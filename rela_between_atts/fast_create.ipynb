# %%
import numpy as np
import tensorflow as tf
import keras
import pandas as pd
import matplotlib.pyplot as plt

# %%
font = {'weight' : 'bold',
        'size'   : 18}
plt.rc('font', **font)

geo_lev = "POA"

# %%
df = pd.read_csv("./output/scores_diff_methods.csv", index_col=0)
df
# Out:
#              forest      baye        lr   GraBoost
# r2        -7.115295 -0.766833 -2.649970 -14.348133
# max_error -0.053656 -0.031948 -0.033719  -0.063107

# %%
df1 = df.loc["r2"]
ax = df1.plot.bar(rot=0)

# %%
df2 = df.loc["max_error"]
ax = df2.plot.bar(rot=0, color="r")
