# %% [markdown]
# # Process to assign EV

# %%
import numpy as np
import tensorflow as tf
import keras
import pandas as pd

# %%
from utils import process_from_census_data, TRS

# %% [markdown]
# ### Import getting model

# %%
model = keras.models.load_model("cnn_20.keras")

# %% [markdown]
# ### Process to get the total at each SA1
# The model selected here is the one that got total SA1 quite close to the actual total - 7819

# %%
EXPECTED_SUM = 7819
sa1_data, sa1_tot = process_from_census_data(geo_lev="SA1", 
                                             normalise=True, 
                                             boxcox=False, 
                                             keep_same=True, 
                                             return_tot=True)

# %%
predicted = model.predict(sa1_data)
predicted = predicted.flatten()
sa1_data["pred_num_EV_percen"] = predicted
sa1_data["pred_num_EV_percen"]
# Out:
# 484/484 [==============================] - 1s 1ms/step
# 20101100101    0.003368
# 20101100102    0.003313
# 20101100105    0.003313
# 20101100106    0.003377
# 20101100107    0.003313
#                  ...
# 21704148034    0.003413
# 21704148035    0.003313
# 29797979991    0.014472
# 29797979992    0.014472
# 29797979993    0.014472
# Name: pred_num_EV_percen, Length: 15481, dtype: float32

# %%
predicted_num = sa1_data["pred_num_EV_percen"] * sa1_tot

predicted_num = predicted_num.fillna(0) #na value because that sa1 has no one
predicted_rounded = TRS(predicted_num, know_tot=EXPECTED_SUM)

print(predicted_num.sum(), predicted_rounded.sum(), EXPECTED_SUM)

sa1_data["pred_num_EV"] = predicted_rounded

print(f"""
Check whether this value has negative:
{True in (sa1_data["pred_num_EV"]<0).unique()}
""")
# Out:
# 9899.301355244243 7819 7819
#
# Check whether this value has negative
# False

# %% [markdown]
# ## Combine to get total EV for each SA1 in the final

# %% [markdown]
# ### Process data

# %%
file_loc = "output/EV_pred"
geo_lev = "SA1"

# %%
df_all = pd.read_csv(f"{file_loc}/{geo_lev}_EV_pred_all.csv")
df_all[geo_lev] = df_all[geo_lev].astype(str)

# %%
dict_num_ev =  dict(zip(sa1_data.index.astype(str), sa1_data["pred_num_EV"]))

# %%
ls_cols_ev_pred = [x for x in df_all.columns if "EV_pred" in x]

# %%
combine_fin_df = df_all[ls_cols_ev_pred+[geo_lev]]

# %% [markdown]
# ## Assigning EV

# %%
combine_fin_df
# Out:
#          EV_pred_forest  EV_pred_baye  EV_pred_lr  EV_pred_GraBoost  \
# 0              0.003988      0.007249   -0.006780          0.001441
# 1              0.002178     -0.002708   -0.001990          0.001441
# 2              0.001904     -0.006483   -0.037701          0.001441
# 3              0.003604      0.003209    0.010351          0.001441
# 4              0.004735      0.001560   -0.013556          0.001441
# ...                 ...           ...         ...               ...
# 1902754        0.001483     -0.000362    0.000023          0.001441
# 1902755        0.001297      0.003203    0.001848          0.001441
# 1902756        0.004118      0.000006   -0.023657          0.001441
# 1902757        0.002197      0.003857    0.001653          0.001441
# 1902758        0.002694     -0.005588   -0.008403          0.001441
#
#          EV_pred_Pearsons          SA1
# 0                0.128262  20302104732
# 1               -0.101160  20302104732
# 2               -0.239749  20302104732
# 3               -0.179596  20302104732
# 4               -0.087372  20302104732
# ...                   ...          ...
# 1902754         -0.076286  21402159223
# 1902755         -0.042461  21402159223
# 1902756          0.089287  21402159223
# 1902757          0.265632  21402159223
# 1902758         -0.379299  21402159223
#
# [1902759 rows x 6 columns]

# %%
# Make sense to have higher, some sa1 does not have households
print(len(dict_num_ev), len(df_all[geo_lev].unique()))
# Out:
# 15481 11964

# %%
dict_thres = {}
ls_df = [] # Note these one will have diff index matching with original to combine later

for zone in df_all[geo_lev].unique():
    print(f"DOING {zone}")
    dict_thres[zone] = {}
    sub_df = combine_fin_df[combine_fin_df[geo_lev]==zone]
    num_ev = dict_num_ev[zone]
    ls_series = []
    for ev_pred in ls_cols_ev_pred:
        sort_df = sub_df.sort_values(ev_pred, ascending=False)
        n = len(sort_df)
        arr_val = ["NO" for _ in range(n)]
        arr_val[:num_ev] = ["YES" for _ in range(num_ev)]
        seri_ev_count = pd.Series(arr_val, index=sort_df.index, name=f"check_{ev_pred}")
        ls_series.append(seri_ev_count)

        # Find thres
        thres = sort_df[ev_pred].iat[num_ev-1]
        dict_thres[zone][ev_pred] = thres
    df_zone = pd.concat(ls_series, axis=1) # note the index
    ls_df.append(df_zone)

# %%
ev_as_df = pd.concat(ls_df)
ev_as_df = ev_as_df.sort_index()
ev_as_df
# Out:
#         check_EV_pred_forest check_EV_pred_baye check_EV_pred_lr  \
# 0                         NO                 NO               NO
# 1                         NO                 NO               NO
# 2                         NO                 NO               NO
# 3                         NO                 NO               NO
# 4                         NO                 NO               NO
# ...                      ...                ...              ...
# 1902754                   NO                 NO               NO
# 1902755                   NO                 NO               NO
# 1902756                   NO                 NO               NO
# 1902757                   NO                 NO               NO
# 1902758                   NO                 NO               NO
#
#         check_EV_pred_GraBoost check_EV_pred_Pearsons
# 0                           NO                     NO
# 1                           NO                     NO
# 2                           NO                     NO
# 3                           NO                     NO
# 4                           NO                     NO
# ...                        ...                    ...
# 1902754                     NO                     NO
# 1902755                     NO                     NO
# 1902756                     NO                     NO
# 1902757                     NO                     NO
# 1902758                     NO                     NO
#
# [1902759 rows x 5 columns]

# %%
final_df_all = pd.concat([combine_fin_df, ev_as_df], axis=1)
final_df_all
# Out:
#          EV_pred_forest  EV_pred_baye  EV_pred_lr  EV_pred_GraBoost  \
# 0              0.003988      0.007249   -0.006780          0.001441
# 1              0.002178     -0.002708   -0.001990          0.001441
# 2              0.001904     -0.006483   -0.037701          0.001441
# 3              0.003604      0.003209    0.010351          0.001441
# 4              0.004735      0.001560   -0.013556          0.001441
# ...                 ...           ...         ...               ...
# 1902754        0.001483     -0.000362    0.000023          0.001441
# 1902755        0.001297      0.003203    0.001848          0.001441
# 1902756        0.004118      0.000006   -0.023657          0.001441
# 1902757        0.002197      0.003857    0.001653          0.001441
# 1902758        0.002694     -0.005588   -0.008403          0.001441
#
#          EV_pred_Pearsons          SA1 check_EV_pred_forest  \
# 0                0.128262  20302104732                   NO
# 1               -0.101160  20302104732                   NO
# 2               -0.239749  20302104732                   NO
# 3               -0.179596  20302104732                   NO
# 4               -0.087372  20302104732                   NO
# ...                   ...          ...                  ...
# 1902754         -0.076286  21402159223                   NO
# 1902755         -0.042461  21402159223                   NO
# 1902756          0.089287  21402159223                   NO
# 1902757          0.265632  21402159223                   NO
# 1902758         -0.379299  21402159223                   NO
#
#         check_EV_pred_baye check_EV_pred_lr check_EV_pred_GraBoost  \
# 0                       NO               NO                     NO
# 1                       NO               NO                     NO
# 2                       NO               NO                     NO
# 3                       NO               NO                     NO
# 4                       NO               NO                     NO
# ...                    ...              ...                    ...
# 1902754                 NO               NO                     NO
# 1902755                 NO               NO                     NO
# 1902756                 NO               NO                     NO
# 1902757                 NO               NO                     NO
# 1902758                 NO               NO                     NO
#
#         check_EV_pred_Pearsons
# 0                           NO
# 1                           NO
# 2                           NO
# 3                           NO
# 4                           NO
# ...                        ...
# 1902754                     NO
# 1902755                     NO
# 1902756                     NO
# 1902757                     NO
# 1902758                     NO
#
# [1902759 rows x 11 columns]

# %%
check_cols = [x for x in final_df_all.columns if "check_" in x]

for c in check_cols:
    print(final_df_all[c].value_counts())

# missing some zones, high chance because the pop synthesis did not synthesize those
# Out:
# check_EV_pred_forest
# NO     1896708
# YES       6051
# Name: count, dtype: int64
# check_EV_pred_baye
# NO     1896708
# YES       6051
# Name: count, dtype: int64
# check_EV_pred_lr
# NO     1896708
# YES       6051
# Name: count, dtype: int64
# check_EV_pred_GraBoost
# NO     1896708
# YES       6051
# Name: count, dtype: int64
# check_EV_pred_Pearsons
# NO     1896708
# YES       6051
# Name: count, dtype: int64

# %%
final_df_all.to_csv("SA1_FIN_EV_assignment.csv", index=False)

# %% [markdown]
# # Mapping to get the final plot

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ### Prep data

# %%
df_pop = df_all.drop(columns=ls_cols_ev_pred+["hhid", "SA1"])
df_pop = pd.concat([df_pop, ev_as_df], axis=1)
df_pop
# Out:
#          hhsize          dwelltype   hhinc  totalvehs         owndwell  \
# 0           3.0     Separate House   350.0        1.0  Being Purchased
# 1           2.0     Separate House  3600.0        0.0      Fully Owned
# 2           2.0     Separate House  1900.0        1.0      Fully Owned
# 3           3.0     Separate House   350.0        3.0      Fully Owned
# 4           2.0     Separate House   800.0        2.0  Being Purchased
# ...         ...                ...     ...        ...              ...
# 1902754     1.0              Other  2850.0        1.0      Fully Owned
# 1902755     1.0     Separate House  3200.0        2.0      Fully Owned
# 1902756     1.0     Separate House  2800.0        1.0  Being Purchased
# 1902757     1.0  Flat or Apartment  3000.0        0.0     Being Rented
# 1902758     1.0     Separate House   700.0        1.0      Fully Owned
#
#         check_EV_pred_forest check_EV_pred_baye check_EV_pred_lr  \
# 0                         NO                 NO               NO
# 1                         NO                 NO               NO
# 2                         NO                 NO               NO
# 3                         NO                 NO               NO
# 4                         NO                 NO               NO
# ...                      ...                ...              ...
# 1902754                   NO                 NO               NO
# 1902755                   NO                 NO               NO
# 1902756                   NO                 NO               NO
# 1902757                   NO                 NO               NO
# 1902758                   NO                 NO               NO
#
#         check_EV_pred_GraBoost check_EV_pred_Pearsons
# 0                           NO                     NO
# 1                           NO                     NO
# 2                           NO                     NO
# 3                           NO                     NO
# 4                           NO                     NO
# ...                        ...                    ...
# 1902754                     NO                     NO
# 1902755                     NO                     NO
# 1902756                     NO                     NO
# 1902757                     NO                     NO
# 1902758                     NO                     NO
#
# [1902759 rows x 10 columns]

# %%
dict_counts_methods_atts = {}
ls_check_methods = [f"check_{x}" for x in ls_cols_ev_pred]
# Check each methods
for method in ls_check_methods:
    dict_counts_methods_atts[method] = {}
    df_ev_own = df_pop[df_pop[method]=="YES"]
    df_ev_own.drop(columns=ls_check_methods)
    for att in df_ev_own.columns:
        val_counts = df_ev_own[att].value_counts()
        dict_counts_methods_atts[method][att] = val_counts.sort_index()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

forest = dict_counts_methods_atts["check_EV_pred_forest"]['hhinc']
baye = dict_counts_methods_atts["check_EV_pred_baye"]['hhinc']
lr = dict_counts_methods_atts["check_EV_pred_lr"]['hhinc']
graboost = dict_counts_methods_atts["check_EV_pred_GraBoost"]['hhinc']
pears = dict_counts_methods_atts["check_EV_pred_Pearsons"]['hhinc']

ax1.scatter(lr.index, lr.values, s=2, c='r', label='Linear Regression', alpha=0.5)
ax1.scatter(baye.index, baye.values, s=2, c='g', label='Bayesian Ridge', alpha=0.5)
ax1.scatter(forest.index, forest.values, s=2, c='b', label='Random Forest', alpha=0.5)
ax1.scatter(pears.index, pears.values, s=2, c='b', label='Pearsons', alpha=0.5)
ax1.scatter(graboost.index, graboost.values, s=2, c='orange', label='Gradient Boosting', alpha=0.5)

plt.xlabel("Income")
plt.ylabel("Number of HH that owns EV")
plt.title("Income for EV prediction SA1")
plt.legend(loc='upper right')

# %%
def to_plot_mul_bars(dict_check, ls_methods, att):
    print(f"PLOTTING {att}")
    X_lab = df_all[att].unique()
    X_lab.sort()
    hold_val = {}

    for method in ls_methods:
        name_check = f"check_EV_pred_{method}"
        series_counts = dict_check[name_check][att]
        arr_val = []
        for val in X_lab:
            if val not in series_counts.index: 
                arr_val.append(0)
            else:
                arr_val.append(series_counts[val])
        hold_val[method] = arr_val

    x = np.arange(len(X_lab))  # the label locations
    width = 0.1  # the width of the bars
    multiplier = 0

    fig, ax = plt.subplots(layout='constrained', figsize=(20, 10))

    for attribute, counts in hold_val.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, counts, width, label=attribute)
        # ax.bar_label(rects, padding=3)
        multiplier += 1

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Number of HHs that have EV')
    ax.set_title(f'Analyse {geo_lev} - {att}')
    ax.set_xticks(x + width, X_lab)
    ax.legend(loc='best', ncols=3)

    plt.show()


ls_methods = ["forest", "baye", "lr", "GraBoost", "Pearsons"]

# %%
ls_atts_pop = [x for x in df_ev_own.columns if "EV" not in x]

# %%
for att in ls_atts_pop:
    to_plot_mul_bars(dict_counts_methods_atts, ls_methods, att)
# Out:
# PLOTTING hhsize
# PLOTTING dwelltype
# PLOTTING hhinc
# PLOTTING totalvehs
# PLOTTING owndwell

# %% [markdown]
# ### Get threshold and see across area

# %%
gdf_poa = gpd.read_file("data/SA1_2021_AUST_SHP_GDA2020.zip")
print(gdf_poa)
gdf_poa.plot()
dict_thres
# Out:
#         SA1_CODE21 CHG_FLAG21  CHG_LBL21 SA2_CODE21  \
# 0      10102100701          0  No change  101021007
# 1      10102100702          0  No change  101021007
# 2      10102100703          0  No change  101021007
# 3      10102100704          0  No change  101021007
# 4      10102100705          0  No change  101021007
# ...            ...        ...        ...        ...
# 61840  90104100407          0  No change  901041004
# 61841  90104100408          0  No change  901041004
# 61842  99797979993          0  No change  997979799
# 61843  99999949999          0  No change  999999499
# 61844  ZZZZZZZZZZZ          0  No change  ZZZZZZZZZ
#
#                                  SA2_NAME21 SA3_CODE21  \
# 0                                 Braidwood      10102
# 1                                 Braidwood      10102
# 2                                 Braidwood      10102
# 3                                 Braidwood      10102
# 4                                 Braidwood      10102
# ...                                     ...        ...
# 61840                        Norfolk Island      90104
# 61841                        Norfolk Island      90104
# 61842  Migratory - Offshore - Shipping (OT)      99797
# 61843                 No usual address (OT)      99999
# 61844                     Outside Australia      ZZZZZ
#
#                                  SA3_NAME21 SA4_CODE21  \
# 0                                Queanbeyan        101
# 1                                Queanbeyan        101
# 2                                Queanbeyan        101
# 3                                Queanbeyan        101
# 4                                Queanbeyan        101
# ...                                     ...        ...
# 61840                        Norfolk Island        901
# 61841                        Norfolk Island        901
# 61842  Migratory - Offshore - Shipping (OT)        997
# 61843                 No usual address (OT)        999
# 61844                     Outside Australia        ZZZ
#
#                                  SA4_NAME21 GCC_CODE21  \
# 0                            Capital Region      1RNSW
# 1                            Capital Region      1RNSW
# 2                            Capital Region      1RNSW
# 3                            Capital Region      1RNSW
# 4                            Capital Region      1RNSW
# ...                                     ...        ...
# 61840                     Other Territories      9OTER
# 61841                     Other Territories      9OTER
# 61842  Migratory - Offshore - Shipping (OT)      99799
# 61843                 No usual address (OT)      99499
# 61844                     Outside Australia      ZZZZZ
#
#                                  GCC_NAME21 STE_CODE21         STE_NAME21  \
# 0                               Rest of NSW          1    New South Wales
# 1                               Rest of NSW          1    New South Wales
# 2                               Rest of NSW          1    New South Wales
# 3                               Rest of NSW          1    New South Wales
# 4                               Rest of NSW          1    New South Wales
# ...                                     ...        ...                ...
# 61840                     Other Territories          9  Other Territories
# 61841                     Other Territories          9  Other Territories
# 61842  Migratory - Offshore - Shipping (OT)          9  Other Territories
# 61843                 No usual address (OT)          9  Other Territories
# 61844                     Outside Australia          Z  Outside Australia
#
#       AUS_CODE21         AUS_NAME21  AREASQKM21  \
# 0            AUS          Australia    362.8727
# 1            AUS          Australia    229.7459
# 2            AUS          Australia      2.3910
# 3            AUS          Australia      1.2816
# 4            AUS          Australia      1.1978
# ...          ...                ...         ...
# 61840        AUS          Australia     10.5956
# 61841        AUS          Australia      2.3801
# 61842        AUS          Australia         NaN
# 61843        AUS          Australia         NaN
# 61844        ZZZ  Outside Australia         NaN
#
#                                               LOCI_URI21  \
# 0      http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 1      http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 2      http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 3      http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 4      http://linked.data.gov.au/dataset/asgsed3/SA1/...
# ...                                                  ...
# 61840  http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 61841  http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 61842  http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 61843  http://linked.data.gov.au/dataset/asgsed3/SA1/...
# 61844  http://linked.data.gov.au/dataset/asgsed3/SA1/...
#
#                                                 geometry
# 0      POLYGON ((149.89111 -35.08989, 149.89181 -35.0...
# 1      POLYGON ((149.73421 -35.36757, 149.74475 -35.3...
# 2      POLYGON ((149.77998 -35.44066, 149.77997 -35.4...
# 3      POLYGON ((149.79744 -35.44148, 149.79779 -35.4...
# 4      POLYGON ((149.79499 -35.44901, 149.79518 -35.4...
# ...                                                  ...
# 61840  MULTIPOLYGON (((167.91662 -29.00960, 167.91659...
# 61841  MULTIPOLYGON (((167.96325 -29.07212, 167.96326...
# 61842                                               None
# 61843                                               None
# 61844                                               None
#
# [61845 rows x 18 columns]
# {'20302104732': {'EV_pred_forest': 0.0019035711595286,
#   'EV_pred_baye': -0.0064830515218224,
#   'EV_pred_lr': -0.0377013754334362,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.2397490594393297},
#  '20801116801': {'EV_pred_forest': 0.0021910804463464,
#   'EV_pred_baye': 0.0009429619451035,
#   'EV_pred_lr': -0.0317641005374967,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.0619608078166317},
#  '20904143211': {'EV_pred_forest': 0.0016921913003242,
#   'EV_pred_baye': -0.0073133085057377,
#   'EV_pred_lr': -0.026647259239742,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3044327646755289},
#  '21001122825': {'EV_pred_forest': 0.003547522162362,
#   'EV_pred_baye': -0.0008830082118278,
#   'EV_pred_lr': 0.0090062358159517,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.064923618993141},
#  '21002123226': {'EV_pred_forest': 0.0022185328628466,
#   'EV_pred_baye': -0.0005309105957807,
#   'EV_pred_lr': -0.0126047988166566,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3248218867225393},
#  '21103126604': {'EV_pred_forest': 0.0012791457122277,
#   'EV_pred_baye': -0.0029460860354498,
#   'EV_pred_lr': -0.0211193380910524,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.2695990828790139},
#  '21105127509': {'EV_pred_forest': 0.002206980380269,
#   'EV_pred_baye': -3.848497745787861e-05,
#   'EV_pred_lr': -0.0281136282285266,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.0268885134605581},
#  '21105128230': {'EV_pred_forest': 0.0026554758428216,
#   'EV_pred_baye': -0.0048029834299417,
#   'EV_pred_lr': -0.0431815113393399,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.0459641616572056},
#  '21201128901': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0064489915562068,
#   'EV_pred_lr': -0.0271534379604191,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.17901746390046},
#  '21201128939': {'EV_pred_forest': 0.0011924724101218,
#   'EV_pred_baye': -0.0042954444870466,
#   'EV_pred_lr': -0.0180849347225603,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3269760792911271},
#  '21202145606': {'EV_pred_forest': 0.0026554758428216,
#   'EV_pred_baye': -0.0048029834299417,
#   'EV_pred_lr': -0.0334463941642437,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.0939787340386045},
#  '21203155636': {'EV_pred_forest': 0.0013525739515734,
#   'EV_pred_baye': -0.0076172293740908,
#   'EV_pred_lr': -0.0496396105727852,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.2357137751565086},
#  '21302134308': {'EV_pred_forest': 0.0010472842063742,
#   'EV_pred_baye': -0.0052995910564742,
#   'EV_pred_lr': -0.0261035402071529,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3248218867225393},
#  '21304157201': {'EV_pred_forest': 0.0021993759870405,
#   'EV_pred_baye': 0.0017714113926562,
#   'EV_pred_lr': -0.0123307222165044,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.0498832550793146},
#  '21305136125': {'EV_pred_forest': 0.002175642826673,
#   'EV_pred_baye': -0.0059913912541595,
#   'EV_pred_lr': -0.0281733793096371,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0

#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.6049190666342339},
#  '20302104212': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0077277971128211,
#   'EV_pred_lr': -0.0434431867480419,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4090082805210329},
#  '20302104213': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0074958120493563,
#   'EV_pred_lr': -0.0365093781698398,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3792934238533223},
#  '20302104215': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0087003159798398,
#   'EV_pred_lr': -0.0613550416812156,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4190555171568673},
#  '20302104216': {'EV_pred_forest': 0.0007929120392788,
#   'EV_pred_baye': -0.0088956114280394,
#   'EV_pred_lr': -0.0458781131915136,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4118839751047549},
#  '20302104217': {'EV_pred_forest': 0.0007603700466837,
#   'EV_pred_baye': -0.0110919495218387,
#   'EV_pred_lr': -0.0452628180190053,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4027286981847753},
#  '20302104218': {'EV_pred_forest': 0.0008296180771356,
#   'EV_pred_baye': -0.0092655455435912,
#   'EV_pred_lr': -0.0562839511542006,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4212423892162073},
# ...
#   'EV_pred_Pearsons': -0.4642065106011926},
#  '20601149722': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0077277971128211,
#   'EV_pred_lr': -0.0458781131915136,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3893458514233992},
#  '20601149723': {'EV_pred_forest': 0.000827867381205,
#   'EV_pred_baye': -0.011122791883316,
#   'EV_pred_lr': -0.0616167170899176,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4989837780395527},
#  '20601149724': {'EV_pred_forest': 0.0243536880427669,
#   'EV_pred_baye': 0.0168790956247863,
#   'EV_pred_lr': 0.260005942046474,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5581458857326602},
#  '20601149725': {'EV_pred_forest': 0.0007837725919149,
#   'EV_pred_baye': -0.0091892517113543,
#   'EV_pred_lr': -0.0558749057753119,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4642065106011926},
#  '20601149726': {'EV_pred_forest': 0.0010455335104436,
#   'EV_pred_baye': -0.0093532117300867,
#   'EV_pred_lr': -0.0516199245061194,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3893458514233992},
#  '20601149801': {'EV_pred_forest': 0.0008542179558513,
#   'EV_pred_baye': -0.0077586394742984,
#   'EV_pred_lr': -0.0431815113393399,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3792986147875648},
#  '20601149802': {'EV_pred_forest': 0.0009441218939295,
#   'EV_pred_baye': -0.0093555436631771,
#   'EV_pred_lr': -0.0442352649816119,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3734762787554824},
#  '20601149803': {'EV_pred_forest': 0.0009441218939295,
#   'EV_pred_baye': -0.0106320172867011,
#   'EV_pred_lr': -0.0457864611882351,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4989837780395527},
#  '20601149804': {'EV_pred_forest': 0.0008296180771356,
#   'EV_pred_baye': -0.0090088013751425,
#   'EV_pred_lr': -0.0634363483608811,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4642065106011926},
#  '20601149805': {'EV_pred_forest': 0.0298719573286279,
#   'EV_pred_baye': 0.0165416299442118,
#   'EV_pred_lr': 0.2781469910196176,
#   'EV_pred_GraBoost': 0.0140437362563356,
#   'EV_pred_Pearsons': 0.4237791005812785},
#  '20601149806': {'EV_pred_forest': 0.0232704378057898,
#   'EV_pred_baye': 0.0201882686712501,
#   'EV_pred_lr': 0.2855155263001875,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.594318626289165},
#  '20601149807': {'EV_pred_forest': 0.0238643780049085,
#   'EV_pred_baye': 0.017016524235419,
#   'EV_pred_lr': 0.0557494092863041,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5505733613748556},
#  '20601149808': {'EV_pred_forest': 0.0009127703858409,
#   'EV_pred_baye': -0.0084010752530546,
#   'EV_pred_lr': -0.0437964490302208,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3893458514233992},
#  '20601149809': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0102175286796176,
#   'EV_pred_lr': -0.0613550416812156,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4190555171568673},
#  '20601149810': {'EV_pred_forest': 0.0008935838308794,
#   'EV_pred_baye': -0.0077732407408754,
#   'EV_pred_lr': -0.032644106028504,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3792986147875648},
#  '20601149811': {'EV_pred_forest': 0.0268918760593994,
#   'EV_pred_baye': 0.0183529681656707,
#   'EV_pred_lr': 0.0652088333857818,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5954662796202621},
#  '20601149812': {'EV_pred_forest': 0.0010472842063742,
#   'EV_pred_baye': -0.0087877768089488,
#   'EV_pred_lr': -0.0513582490974174,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4190555171568673},
#  '20601149813': {'EV_pred_forest': 0.030728072493326,
#   'EV_pred_baye': 0.0172660810058993,
#   'EV_pred_lr': 0.2814303956868638,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5539697373509473},
#  '20601149814': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0087003159798398,
#   'EV_pred_lr': -0.0431815113393399,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4190555171568673},
#  '20601149815': {'EV_pred_forest': 0.0290700023427745,
#   'EV_pred_baye': 0.0191087378643661,
#   'EV_pred_lr': 0.2507058090383229,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5977808749243415},
#  '20601149816': {'EV_pred_forest': 0.0253101850402015,
#   'EV_pred_baye': 0.0182374883669653,
#   'EV_pred_lr': 0.0974708982182089,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.4906165891612897},
#  '20601149817': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0106628596481783,
#   'EV_pred_lr': -0.0513582490974174,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4844837874743625},
#  '20601149818': {'EV_pred_forest': 0.000811358057178,
#   'EV_pred_baye': -0.0078995236186302,
#   'EV_pred_lr': -0.0558749057753119,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3779986673822496},
#  '20601149819': {'EV_pred_forest': 0.00070034578572,
#   'EV_pred_baye': -0.0082185717094361,
#   'EV_pred_lr': -0.0403063252823314,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3893458514233992},
#  '20601149820': {'EV_pred_forest': 0.0282699100386149,
#   'EV_pred_baye': 0.0177026639184516,
#   'EV_pred_lr': 0.2800353903942838,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5287610594003381},
#  '20601149821': {'EV_pred_forest': 0.0010472842063742,
#   'EV_pred_baye': -0.0064489915562068,
#   'EV_pred_lr': -0.0336535152155408,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3373573283968628},
#  '20601149822': {'EV_pred_forest': 0.031947656365153,
#   'EV_pred_baye': 0.0177304175960826,
#   'EV_pred_lr': 0.2985555099640634,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.565071335357313},
#  '20601149823': {'EV_pred_forest': 0.0010455335104436,
#   'EV_pred_baye': -0.00984720393084,
#   'EV_pred_lr': -0.053763261105411,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3647986242223746},
#  '20601149824': {'EV_pred_forest': 0.00107188408509,
#   'EV_pred_baye': -0.0081877293479588,
#   'EV_pred_lr': -0.0436617753765203,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3792986147875648},
#  '20601149825': {'EV_pred_forest': 0.0289323682373425,
#   'EV_pred_baye': 0.0195454822443289,
#   'EV_pred_lr': 0.2855155263001875,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5657201282653384},
#  '20601149826': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0081877293479588,
#   'EV_pred_lr': -0.0434431867480419,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3647986242223746},
#  '20601149827': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0088956114280394,
#   'EV_pred_lr': -0.0384934536670061,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3647986242223746},
#  '20601149828': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.007941143017917,
#   'EV_pred_lr': -0.0405453472557966,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4642065106011926},
#  '20601149829': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0106628596481783,
#   'EV_pred_lr': -0.0480214497908052,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4844837874743625},
#  '20601149830': {'EV_pred_forest': 0.0009117733060767,
#   'EV_pred_baye': -0.0077277971128211,
#   'EV_pred_lr': -0.0513582490974174,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3893458514233992},
#  '20601149831': {'EV_pred_forest': 0.0010225588407895,
#   'EV_pred_baye': -0.0091602482149775,
#   'EV_pred_lr': -0.0508176363703797,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4122179875746562},
#  '20601149832': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0077586394742984,
#   'EV_pred_lr': -0.0613550416812156,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4090082805210329},
#  '20601149833': {'EV_pred_forest': 0.0229967763604512,
#   'EV_pred_baye': 0.0175652353078189,
#   'EV_pred_lr': 0.2781469910196176,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5287610594003381},
#  '20601149834': {'EV_pred_forest': 0.026873162529969,
#   'EV_pred_baye': 0.0170851488973576,
#   'EV_pred_lr': 0.0739762652114486,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5392999063781829},
#  '20602111001': {'EV_pred_forest': 0.0295294790324244,
#   'EV_pred_baye': 0.0199895358042344,
#   'EV_pred_lr': 0.0803606966022721,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5668783113155454},
#  '20602111002': {'EV_pred_forest': 0.0252460080186051,
#   'EV_pred_baye': 0.0177026639184516,
#   'EV_pred_lr': 0.0737145898027466,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5088862016264273},
#  '20602111003': {'EV_pred_forest': 0.026763413420214,
#   'EV_pred_baye': 0.0175652353078189,
#   'EV_pred_lr': 0.2855155263001875,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5487526933921547},
#  '20602111004': {'EV_pred_forest': 0.0007929120392788,
#   'EV_pred_baye': -0.0077277971128211,
#   'EV_pred_lr': -0.0442236779606042,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.393730490824903},
#  '20602111005': {'EV_pred_forest': 0.0010271842593856,
#   'EV_pred_baye': -0.0065603156528215,
#   'EV_pred_lr': -0.0455244934277074,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4090082805210329},
#  '20602111006': {'EV_pred_forest': 0.0290700023427745,
#   'EV_pred_baye': 0.0175652353078189,
#   'EV_pred_lr': 0.2935298799024921,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5462065955140292},
#  '20602111007': {'EV_pred_forest': 0.0008542179558513,
#   'EV_pred_baye': -0.0082185717094361,
#   'EV_pred_lr': -0.0458781131915136,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4090082805210329},
#  '20602111008': {'EV_pred_forest': 0.0008296180771356,
#   'EV_pred_baye': -0.0082185717094361,
#   'EV_pred_lr': -0.0562839511542006,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3792986147875648},
#  '20602111009': {'EV_pred_forest': 0.0012913887552935,
#   'EV_pred_baye': -0.0043936707479046,
#   'EV_pred_lr': -0.0277045828496379,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.2297018228034953},
#  '20602111010': {'EV_pred_forest': 0.0251683976820195,
#   'EV_pred_baye': 0.0199895358042344,
#   'EV_pred_lr': 0.2855155263001875,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.563892904379763},
#  '20602111011': {'EV_pred_forest': 0.0284337507999543,
#   'EV_pred_baye': 0.0183529681656707,
#   'EV_pred_lr': 0.2645353150433429,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5954662796202621},
#  '20602111012': {'EV_pred_forest': 0.0272163833494714,
#   'EV_pred_baye': 0.0194978755365715,
#   'EV_pred_lr': 0.0795333693908701,
#   'EV_pred_GraBoost': 0.0145391346841158,
#   'EV_pred_Pearsons': 0.6246791980520043},
#  '20602111013': {'EV_pred_forest': 0.0230689830953823,
#   'EV_pred_baye': 0.0168193203375473,
#   'EV_pred_lr': 0.0688100395519874,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.4599100179588069},
#  '20602111014': {'EV_pred_forest': 0.0267821269496444,
#   'EV_pred_baye': 0.0186676185526562,
#   'EV_pred_lr': 0.0765386347781587,
#   'EV_pred_GraBoost': 0.0145391346841158,
#   'EV_pred_Pearsons': 0.4571292550691162},
#  '20602111015': {'EV_pred_forest': 0.0268918760593994,
#   'EV_pred_baye': 0.0186079486095375,
#   'EV_pred_lr': 0.0700589125331759,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5295579174279436},
#  '20602111016': {'EV_pred_forest': 0.0010586690267129,
#   'EV_pred_baye': -0.0071254873005786,
#   'EV_pred_lr': -0.0434153283522044,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3792986147875648},
#  '20602111017': {'EV_pred_forest': 0.0009127703858409,
#   'EV_pred_baye': -0.0076944935050899,
#   'EV_pred_lr': -0.0452605321909583,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3976267464075517},
#  '20602111018': {'EV_pred_forest': 0.0008296180771356,
#   'EV_pred_baye': -0.0074395913834926,
#   'EV_pred_lr': -0.0458781131915136,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4090082805210329},
#  '20602111019': {'EV_pred_forest': 0.0208834749951391,
#   'EV_pred_baye': 0.0168193203375473,
#   'EV_pred_lr': 0.0688100395519874,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5312475626049973},
#  '20602111022': {'EV_pred_forest': 0.0007603700466837,
#   'EV_pred_baye': -0.0098131439652244,
#   'EV_pred_lr': -0.0636980237695831,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4939161763346607},
#  '20602111201': {'EV_pred_forest': 0.0288860487633726,
#   'EV_pred_baye': 0.0184903967763033,
#   'EV_pred_lr': 0.3208895879549091,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5878937552624575},
#  '20602111202': {'EV_pred_forest': 0.0248916394818221,
#   'EV_pred_baye': 0.0193844758691184,
#   'EV_pred_lr': 0.0739762652114486,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.6143310194635458},
#  '20602111203': {'EV_pred_forest': 0.0009127703858409,
#   'EV_pred_baye': -0.0084010752530546,
#   'EV_pred_lr': -0.0431815113393399,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.3893458514233992},
#  '20602111204': {'EV_pred_forest': 0.0229338246673809,
#   'EV_pred_baye': 0.0161317302552402,
#   'EV_pred_lr': 0.0688100395519874,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.4431784369243754},
#  '20602111205': {'EV_pred_forest': 0.0250913703737159,
#   'EV_pred_baye': 0.0175652353078189,
#   'EV_pred_lr': 0.2954265552786679,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5462146388302922},
#  '20602111206': {'EV_pred_forest': 0.0008296180771356,
#   'EV_pred_baye': -0.0082185717094361,
#   'EV_pred_lr': -0.0616167170899176,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4090082805210329},
#  '20602111207': {'EV_pred_forest': 0.0008881705071251,
#   'EV_pred_baye': -0.0106628596481783,
#   'EV_pred_lr': -0.0400919997632897,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4844837874743625},
#  '20602111208': {'EV_pred_forest': 0.0227517031330514,
#   'EV_pred_baye': 0.0168193203375473,
#   'EV_pred_lr': 0.0541534264415281,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5371321599606217},
#  '20602111209': {'EV_pred_forest': 0.0248266241837122,
#   'EV_pred_baye': 0.0179183450550371,
#   'EV_pred_lr': 0.0823564350935265,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5295579174279436},
#  '20602111210': {'EV_pred_forest': 0.0246394408882508,
#   'EV_pred_baye': 0.0170851488973576,
#   'EV_pred_lr': 0.0605610089062895,
#   'EV_pred_GraBoost': 0.0143381802846032,
#   'EV_pred_Pearsons': 0.5129435750964765},
#  '20602111211': {'EV_pred_forest': 0.0226588495316421,
#   'EV_pred_baye': 0.0173132851199212,
#   'EV_pred_lr': 0.0609700542851782,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.4800245645773797},
#  '20602111212': {'EV_pred_forest': 0.0202740118995977,
#   'EV_pred_baye': 0.0194978755365715,
#   'EV_pred_lr': 0.0765386347781587,
#   'EV_pred_GraBoost': 0.0113355570767535,
#   'EV_pred_Pearsons': 0.5295579174279436},
#  '20602111213': {'EV_pred_forest': 0.0208357460429611,
#   'EV_pred_baye': 0.016869253101924,
#   'EV_pred_lr': 0.0700589125331759,
#   'EV_pred_GraBoost': 0.0137273919047346,
#   'EV_pred_Pearsons': 0.5731129619579551},
#  '20602111214': {'EV_pred_forest': 0.0008296180771356,
#   'EV_pred_baye': -0.011122791883316,
#   'EV_pred_lr': -0.0434153283522044,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4497065200360024},
#  '20602111215': {'EV_pred_forest': 0.0008747785087041,
#   'EV_pred_baye': -0.0106320172867011,
#   'EV_pred_lr': -0.0520352167079244,
#   'EV_pred_GraBoost': 0.0014407150466994,
#   'EV_pred_Pearsons': -0.4989837780395527},
#  ...}

# %%
data_df_build = {
    "SA1_CODE21": []
}

for zone in dict_thres:
    data_df_build["SA1_CODE21"].append(zone)
    for method in dict_thres[zone]:
        me_n = method.split("_")[-1]
        if me_n not in data_df_build:
            data_df_build[me_n] = [dict_thres[zone][method]]
        else:
            data_df_build[me_n].append(dict_thres[zone][method])

df_thres_diff = pd.DataFrame(data_df_build)
df_thres_diff
vic_gpd = gdf_poa.merge(df_thres_diff, on="SA1_CODE21")
vic_gpd.plot()
# Out:
# <Axes: >

# %%
vic_gpd.plot(column="forest", legend=True, legend_kwds={"label": "Random forest EV thres SA1"})
vic_gpd.plot(column="baye", legend=True, legend_kwds={"label": "Bayesian EV thres SA1"})
vic_gpd.plot(column="lr", legend=True, legend_kwds={"label": "Linear Regression EV thres SA1"})
vic_gpd.plot(column="Pearsons", legend=True, legend_kwds={"label": "Pearons EV thres SA1"})
vic_gpd.plot(column="GraBoost", legend=True, legend_kwds={"label": "Gradient Boosting EV thres SA1"})
# Out:
# <Axes: >
