# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import geopandas as gpd
import matplotlib.pyplot as plt
import warnings
from matplotlib.colors import ListedColormap

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dropout

from tensorflow.keras.regularizers import l1, l2

# %%
poa = gpd.read_file("Shape\poa_selected.gpkg")
sa1 = gpd.read_file("Shape\sa1_to_poa.gpkg")
sa1 = sa1[["SA1_CODE21", "POA_CODE21", "geometry"]]
poa = poa[["POA_CODE21", "geometry"]]

# %%
# Import Rego Data 
rego = pd.read_csv("Data\poa_ev.csv")
# Import synthetic populaiton
synthetic = pd.read_csv("Data\clean1.1_data.csv")
synthetic["SA1"] = synthetic["SA1"].astype(str)
synthetic_merged = sa1.merge(synthetic, left_on="SA1_CODE21", right_on="SA1", how="inner")

# %%
rego["POA_CODE21"] = rego["POA_CODE21"].astype(str)
total_evs = synthetic_merged.merge(rego, left_on="POA_CODE21", right_on="POA_CODE21", how="inner").drop_duplicates(subset=["POA_CODE21"])
total_evs = total_evs[["POA_CODE21", "SA1_CODE21", "TOTAL1"]]

# %%
categorical_columns = ["dwelltype_Flat or Apartment", "dwelltype_Other", "dwelltype_Separate House", "dwelltype_Terrace/Townhouse",
                       "owndwell_Being Purchased", "owndwell_Being Rented", "owndwell_Fully Owned", "owndwell_Occupied Rent-Free", "owndwell_Something Else"]

hist_values = []
num_bins = 10 
labels = []

postcodes = total_evs.merge(synthetic_merged, left_on="POA_CODE21", right_on="POA_CODE21", how="right").dropna()["POA_CODE21"].unique()

for postcode in postcodes:
    hist_values_postcode = []
    selected = synthetic_merged[synthetic_merged["POA_CODE21"] == postcode]

    for attribute in ["INC", "TOTALVEHS", "HHSIZE"]:
        hist, _ = np.histogram(selected[attribute], bins=num_bins)
        hist_values_postcode.extend(hist)
    
    categorical_sums = selected[categorical_columns].sum().values
    hist_values_postcode.extend(categorical_sums)

    hist_values.append(hist_values_postcode)
    labels.append(rego[rego["POA_CODE21"] == postcode]["TOTAL1"].values[0])

data = np.array(hist_values)
labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
print(len(X_train), len(X_test), len(X_val))
data.shape[0]
# Out:
# 201 29 51
# 281

# %%
# Split your data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Define the noise level and create augmented data
noise_level = 0.05
augmented_X_train_list = []
augmented_y_train_list = []

for _ in range(1):
    X_train_noise = noise_level * np.random.randn(X_train.shape[0], X_train.shape[1])
    y_train_noise = noise_level * np.random.randn(y_train.shape[0])
    
    augmented_X_train = X_train + X_train_noise
    augmented_y_train = y_train + y_train_noise
    
    augmented_X_train_list.append(augmented_X_train)
    augmented_y_train_list.append(augmented_y_train)

# Concatenate the augmented data
X_train_augmented = np.concatenate(augmented_X_train_list, axis=0)
y_train_augmented = np.concatenate(augmented_y_train_list, axis=0)

# Define a custom loss function
def custom_loss(y_true, y_pred):
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    penalty = tf.reduce_mean(tf.square(tf.maximum(0.0, -y_pred)))
    total_loss = mse + penalty    
    return total_loss

# Initialize the MLP model
continue_training = True

while continue_training:
    # Initialize a new model instance
    mlp_model = Sequential([
        Dense(64, activation='relu', input_shape=(data.shape[1],)),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'), 
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(8, activation='relu'),
        Dense(1)
    ])

    # Compile the new model
    optimizer = Adam(learning_rate=5e-5)
    mlp_model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mean_absolute_error'])

    # Train the model
    history = mlp_model.fit(X_train_augmented, y_train_augmented, epochs=80, batch_size=X_train_augmented.shape[0], validation_data=(X_val, y_val), verbose=0)
    
    # Make predictions on the test set
    predictions = mlp_model.predict(X_test)
    
    # Check if there are any negative predictions
    if np.any(predictions < 0):
        print("Model predicted negative numbers. Retraining...")
        continue_training = True
    else:
        print("Model did not predict negative numbers. Stopping training.")
        continue_training = False

# Evaluate the model on the test set
loss = mlp_model.evaluate(X_test, y_test)
print("Test loss:", loss)

# Plot and save the learn plot
learn_plot = plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.savefig('Plots/learn_plot_my_mode12.png')
plt.show()

# Make predictions on the entire dataset
predicted = mlp_model.predict(data)

# Add predictions to your data frame
total_evs["pred"] = predicted

# Merge dataframes and handle missing values
pred_poa = poa.merge(total_evs, left_on="POA_CODE21", right_on="POA_CODE21", how="outer")
pred_poa.loc[pd.isna(pred_poa["TOTAL1"]), "TOTAL1"] = 0
pred_poa.loc[pd.isna(pred_poa["pred"]), "pred"] = 0

# Plot the predicted and actual data
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
pred_poa.plot(column="pred", ax=axes[0], legend=True, cmap='viridis')
axes[0].set_xticks([])
axes[0].set_yticks([])
axes[0].set_title("Predicted Data")

pred_poa.plot(column="TOTAL1", ax=axes[1], legend=True, cmap='viridis')
axes[1].set_xticks([])
axes[1].set_yticks([])
axes[1].set_title("Actual Data")

plt.show()

# Print sums of total values and min values
print(pred_poa["TOTAL1"].sum(), pred_poa["pred"].sum())
print(pred_poa["TOTAL1"].min(), pred_poa["pred"].min())
# Out:
# 1/1 [==============================] - 0s 66ms/step
# Model predicted negative numbers. Retraining...
# 1/1 [==============================] - 0s 68ms/step
# Model predicted negative numbers. Retraining...
# 1/1 [==============================] - 0s 66ms/step
# Model predicted negative numbers. Retraining...
# 1/1 [==============================] - 0s 113ms/step
# Model did not predict negative numbers. Stopping training.
# 1/1 [==============================] - 0s 20ms/step - loss: 7.5676 - mean_absolute_error: 7.5676
# Test loss: [7.567614555358887, 7.567614555358887]
# 9/9 [==============================] - 0s 1ms/step
# 6215.0 5395.9165
# 0.0 0.0

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
training_loss_series = pd.Series(training_loss, name='Training Loss')
validation_loss_series = pd.Series(validation_loss, name='Validation Loss')
training_loss_series.to_csv("Data/training_loss.csv", index=False)
validation_loss_series.to_csv("Data/validation_loss.csv", index=False)

# %%
mlp_model.save("Data\good_model10_final.h5")
# Out:
# c:\Users\danla\anaconda3\envs\fYP\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)


noise_level = 0.05  # Adjust the noise level as needed
augmented_X_train_list = []
augmented_y_train_list = []

for _ in range(1):
    X_train_noise = noise_level * np.random.randn(X_train.shape[0], X_train.shape[1])
    y_train_noise = noise_level * np.random.randn(y_train.shape[0])
    
    augmented_X_train = X_train + X_train_noise
    augmented_y_train = y_train + y_train_noise
    
    augmented_X_train_list.append(augmented_X_train)
    augmented_y_train_list.append(augmented_y_train)

# Concatenate the augmented data
X_train_augmented = np.concatenate(augmented_X_train_list, axis=0)
y_train_augmented = np.concatenate(augmented_y_train_list, axis=0)

def custom_loss(y_true, y_pred):
    # Compute the mean squared error
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    
    # Penalize negative predictions (adjust the penalty weight as needed)
    penalty = tf.reduce_mean(tf.square(tf.maximum(0.0, -y_pred)))
    
    # Combine the MSE and penalty terms (adjust the weighting as needed)
    total_loss = mse + penalty    
    return total_loss

mlp_model = Sequential([
    Dense(64, activation='relu', input_shape=(data.shape[1],)),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'), 
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)
])

# mlp_model = Sequential([
#     Dense(64, activation='relu', input_shape=(data.shape[1],)),
#     Dense(64, activation='relu'),
#     Dense(32, activation='relu'), 
#     Dense(32, activation='relu'),
#     Dense(32, activation='relu'),
#     Dense(16, activation='relu'),
#     Dense(1)
# ])

optimizer = Adam(learning_rate=5e-5)

# 'mean_absolute_error'

# Reshape your data to add a channel dimension
# X_train_mlp = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val_mlp = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test_mlp = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# X_train_mlp = X_train_augmented.reshape(X_train_augmented.shape[0], X_train_augmented.shape[1], 1)
# y_train = y_train_augmented
X_train_mlp = X_train
y_train = y_train

continue_training = True

while continue_training:
    mlp_model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mean_absolute_error'])
    # Split your data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.1, random_state=42)

    # Train the model
    history = mlp_model.fit(X_train, y_train, epochs=100, batch_size=X_train.shape[0], validation_data=(X_val_mlp, y_val))
    
    # Make predictions on the test set
    predictions = mlp_model.predict(X_test)
    
    # Check if there are any negative predictions
    if np.any(predictions < -1):
        print("Model predicted negative numbers. Retraining...")
        continue_training = True
    else:
        print("Model did not predict negative numbers. Stopping training.")
        continue_training = False

# Evaluate the model on the test set
loss = mlp_model.evaluate(X_test_mlp, y_test)
print("Test loss:", loss)
learn_plot = plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.savefig('Plots\learn_plot_my_model7.png')
plt.show()



predicted = mlp_model.predict(data)
total_evs["pred"] = predicted
display(total_evs)
pred_poa = poa.merge(total_evs, left_on="POA_CODE21", right_on="POA_CODE21", how="outer")
pred_poa.loc[pd.isna(pred_poa["TOTAL1"]), "TOTAL1"] = 0
pred_poa.loc[pd.isna(pred_poa["pred"]), "pred"] = 0

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
pred_poa.plot(column="pred", ax=axes[0], legend=True, cmap='viridis')
axes[0].set_xticks([])
axes[0].set_yticks([])
axes[0].set_title("Predicted Data")

pred_poa.plot(column="TOTAL1", ax=axes[1], legend=True, cmap='viridis')
axes[1].set_xticks([])
axes[1].set_yticks([])
axes[1].set_title("Actual Data")

plt.show()
print(pred_poa["TOTAL1"].sum(), pred_poa["pred"].sum())
print(pred_poa["TOTAL1"].min(), pred_poa["pred"].min())
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 174.1950 - mean_absolute_error: 174.1950 - val_loss: 201.7424 - val_mean_absolute_error: 201.7424
# Epoch 2/100
# 1/1 [==============================] - 0s 30ms/step - loss: 169.1259 - mean_absolute_error: 169.1259 - val_loss: 195.7698 - val_mean_absolute_error: 195.7698
# Epoch 3/100
# 1/1 [==============================] - 0s 30ms/step - loss: 164.0585 - mean_absolute_error: 164.0585 - val_loss: 189.8069 - val_mean_absolute_error: 189.8069
# Epoch 4/100
# 1/1 [==============================] - 0s 28ms/step - loss: 158.9962 - mean_absolute_error: 158.9962 - val_loss: 183.8553 - val_mean_absolute_error: 183.8553
# Epoch 5/100
# 1/1 [==============================] - 0s 26ms/step - loss: 153.9458 - mean_absolute_error: 153.9458 - val_loss: 177.9152 - val_mean_absolute_error: 177.9152
# Epoch 6/100
# 1/1 [==============================] - 0s 27ms/step - loss: 148.9037 - mean_absolute_error: 148.9037 - val_loss: 171.9837 - val_mean_absolute_error: 171.9837
# Epoch 7/100
# 1/1 [==============================] - 0s 30ms/step - loss: 143.8737 - mean_absolute_error: 143.8737 - val_loss: 166.0739 - val_mean_absolute_error: 166.0739
# Epoch 8/100
# 1/1 [==============================] - 0s 27ms/step - loss: 138.8603 - mean_absolute_error: 138.8603 - val_loss: 160.1651 - val_mean_absolute_error: 160.1651
# Epoch 9/100
# 1/1 [==============================] - 0s 27ms/step - loss: 133.8534 - mean_absolute_error: 133.8534 - val_loss: 154.2715 - val_mean_absolute_error: 154.2715
# Epoch 10/100
# 1/1 [==============================] - 0s 29ms/step - loss: 128.8609 - mean_absolute_error: 128.8609 - val_loss: 148.3896 - val_mean_absolute_error: 148.3896
# Epoch 11/100
# 1/1 [==============================] - 0s 28ms/step - loss: 123.8837 - mean_absolute_error: 123.8837 - val_loss: 142.5309 - val_mean_absolute_error: 142.5309
# Epoch 12/100
# 1/1 [==============================] - 0s 28ms/step - loss: 118.9228 - mean_absolute_error: 118.9228 - val_loss: 136.7016 - val_mean_absolute_error: 136.7016
# Epoch 13/100
# 1/1 [==============================] - 0s 27ms/step - loss: 113.9829 - mean_absolute_error: 113.9829 - val_loss: 130.9173 - val_mean_absolute_error: 130.9173
# Epoch 14/100
# 1/1 [==============================] - 0s 26ms/step - loss: 109.0704 - mean_absolute_error: 109.0704 - val_loss: 125.1661 - val_mean_absolute_error: 125.1661
# Epoch 15/100
# 1/1 [==============================] - 0s 28ms/step - loss: 104.1772 - mean_absolute_error: 104.1772 - val_loss: 119.3828 - val_mean_absolute_error: 119.3828
# Epoch 16/100
# 1/1 [==============================] - 0s 27ms/step - loss: 99.2926 - mean_absolute_error: 99.2926 - val_loss: 113.6082 - val_mean_absolute_error: 113.6082
# Epoch 17/100
# 1/1 [==============================] - 0s 28ms/step - loss: 94.4011 - mean_absolute_error: 94.4011 - val_loss: 107.8144 - val_mean_absolute_error: 107.8144
# Epoch 18/100
# 1/1 [==============================] - 0s 26ms/step - loss: 89.5042 - mean_absolute_error: 89.5042 - val_loss: 102.0155 - val_mean_absolute_error: 102.0155
# Epoch 19/100
# 1/1 [==============================] - 0s 29ms/step - loss: 84.6020 - mean_absolute_error: 84.6020 - val_loss: 96.1758 - val_mean_absolute_error: 96.1758
# Epoch 20/100
# 1/1 [==============================] - 0s 34ms/step - loss: 79.6766 - mean_absolute_error: 79.6766 - val_loss: 90.2659 - val_mean_absolute_error: 90.2659
# Epoch 21/100
# 1/1 [==============================] - 0s 30ms/step - loss: 74.7178 - mean_absolute_error: 74.7178 - val_loss: 84.2873 - val_mean_absolute_error: 84.2873
# Epoch 22/100
# 1/1 [==============================] - 0s 28ms/step - loss: 69.7278 - mean_absolute_error: 69.7278 - val_loss: 78.2740 - val_mean_absolute_error: 78.2740
# Epoch 23/100
# 1/1 [==============================] - 0s 28ms/step - loss: 64.6854 - mean_absolute_error: 64.6854 - val_loss: 72.1468 - val_mean_absolute_error: 72.1468
# Epoch 24/100
# 1/1 [==============================] - 0s 27ms/step - loss: 59.5568 - mean_absolute_error: 59.5568 - val_loss: 65.9510 - val_mean_absolute_error: 65.9510
# Epoch 25/100
# 1/1 [==============================] - 0s 28ms/step - loss: 54.3244 - mean_absolute_error: 54.3244 - val_loss: 59.6844 - val_mean_absolute_error: 59.6844
# Epoch 26/100
# 1/1 [==============================] - 0s 29ms/step - loss: 48.9727 - mean_absolute_error: 48.9727 - val_loss: 53.2159 - val_mean_absolute_error: 53.2159
# Epoch 27/100
# 1/1 [==============================] - 0s 26ms/step - loss: 43.5178 - mean_absolute_error: 43.5178 - val_loss: 46.6959 - val_mean_absolute_error: 46.6959
# Epoch 28/100
# 1/1 [==============================] - 0s 29ms/step - loss: 38.0967 - mean_absolute_error: 38.0967 - val_loss: 40.0848 - val_mean_absolute_error: 40.0848
# Epoch 29/100
# 1/1 [==============================] - 0s 37ms/step - loss: 32.7476 - mean_absolute_error: 32.7476 - val_loss: 33.9881 - val_mean_absolute_error: 33.9881
# Epoch 30/100
# 1/1 [==============================] - 0s 37ms/step - loss: 27.6472 - mean_absolute_error: 27.6472 - val_loss: 29.2040 - val_mean_absolute_error: 29.2040
# Epoch 31/100
# 1/1 [==============================] - 0s 31ms/step - loss: 23.6363 - mean_absolute_error: 23.6363 - val_loss: 27.2218 - val_mean_absolute_error: 27.2218
# Epoch 32/100
# 1/1 [==============================] - 0s 29ms/step - loss: 21.4532 - mean_absolute_error: 21.4532 - val_loss: 26.7615 - val_mean_absolute_error: 26.7615
# Epoch 33/100
# 1/1 [==============================] - 0s 28ms/step - loss: 20.8906 - mean_absolute_error: 20.8906 - val_loss: 26.6801 - val_mean_absolute_error: 26.6801
# Epoch 34/100
# 1/1 [==============================] - 0s 26ms/step - loss: 21.2582 - mean_absolute_error: 21.2582 - val_loss: 26.4985 - val_mean_absolute_error: 26.4985
# Epoch 35/100
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5854 - mean_absolute_error: 21.5854 - val_loss: 26.0317 - val_mean_absolute_error: 26.0317
# Epoch 36/100
# 1/1 [==============================] - 0s 28ms/step - loss: 21.6985 - mean_absolute_error: 21.6985 - val_loss: 25.4770 - val_mean_absolute_error: 25.4770
# Epoch 37/100
# 1/1 [==============================] - 0s 27ms/step - loss: 21.4625 - mean_absolute_error: 21.4625 - val_loss: 24.4414 - val_mean_absolute_error: 24.4414
# Epoch 38/100
# 1/1 [==============================] - 0s 26ms/step - loss: 20.8112 - mean_absolute_error: 20.8112 - val_loss: 23.0715 - val_mean_absolute_error: 23.0715
# Epoch 39/100
# 1/1 [==============================] - 0s 26ms/step - loss: 19.7854 - mean_absolute_error: 19.7854 - val_loss: 21.2656 - val_mean_absolute_error: 21.2656
# Epoch 40/100
# 1/1 [==============================] - 0s 28ms/step - loss: 18.4306 - mean_absolute_error: 18.4306 - val_loss: 19.2471 - val_mean_absolute_error: 19.2471
# Epoch 41/100
# 1/1 [==============================] - 0s 27ms/step - loss: 16.8645 - mean_absolute_error: 16.8645 - val_loss: 17.2715 - val_mean_absolute_error: 17.2715
# Epoch 42/100
# 1/1 [==============================] - 0s 26ms/step - loss: 15.1955 - mean_absolute_error: 15.1955 - val_loss: 15.6279 - val_mean_absolute_error: 15.6279
# Epoch 43/100
# 1/1 [==============================] - 0s 28ms/step - loss: 13.6772 - mean_absolute_error: 13.6772 - val_loss: 14.0033 - val_mean_absolute_error: 14.0033
# Epoch 44/100
# 1/1 [==============================] - 0s 26ms/step - loss: 12.3389 - mean_absolute_error: 12.3389 - val_loss: 12.2712 - val_mean_absolute_error: 12.2712
# Epoch 45/100
# 1/1 [==============================] - 0s 24ms/step - loss: 11.4793 - mean_absolute_error: 11.4793 - val_loss: 11.9371 - val_mean_absolute_error: 11.9371
# Epoch 46/100
# 1/1 [==============================] - 0s 27ms/step - loss: 11.3538 - mean_absolute_error: 11.3538 - val_loss: 12.6333 - val_mean_absolute_error: 12.6333
# Epoch 47/100
# 1/1 [==============================] - 0s 26ms/step - loss: 11.7473 - mean_absolute_error: 11.7473 - val_loss: 13.2668 - val_mean_absolute_error: 13.2668
# Epoch 48/100
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2909 - mean_absolute_error: 12.2909 - val_loss: 13.5330 - val_mean_absolute_error: 13.5330
# Epoch 49/100
# 1/1 [==============================] - 0s 27ms/step - loss: 12.7030 - mean_absolute_error: 12.7030 - val_loss: 13.4268 - val_mean_absolute_error: 13.4268
# Epoch 50/100
# 1/1 [==============================] - 0s 28ms/step - loss: 12.7810 - mean_absolute_error: 12.7810 - val_loss: 12.9215 - val_mean_absolute_error: 12.9215
# Epoch 51/100
# 1/1 [==============================] - 0s 28ms/step - loss: 12.5770 - mean_absolute_error: 12.5770 - val_loss: 12.1655 - val_mean_absolute_error: 12.1655
# Epoch 52/100
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1642 - mean_absolute_error: 12.1642 - val_loss: 11.2913 - val_mean_absolute_error: 11.2913
# Epoch 53/100
# 1/1 [==============================] - 0s 26ms/step - loss: 11.6492 - mean_absolute_error: 11.6492 - val_loss: 10.3493 - val_mean_absolute_error: 10.3493
# Epoch 54/100
# 1/1 [==============================] - 0s 27ms/step - loss: 11.1122 - mean_absolute_error: 11.1122 - val_loss: 9.6090 - val_mean_absolute_error: 9.6090
# Epoch 55/100
# 1/1 [==============================] - 0s 27ms/step - loss: 10.7392 - mean_absolute_error: 10.7392 - val_loss: 9.1666 - val_mean_absolute_error: 9.1666
# Epoch 56/100
# 1/1 [==============================] - 0s 26ms/step - loss: 10.6105 - mean_absolute_error: 10.6105 - val_loss: 9.1750 - val_mean_absolute_error: 9.1750
# Epoch 57/100
# 1/1 [==============================] - 0s 27ms/step - loss: 10.7087 - mean_absolute_error: 10.7087 - val_loss: 9.4192 - val_mean_absolute_error: 9.4192
# Epoch 58/100
# 1/1 [==============================] - 0s 27ms/step - loss: 10.9056 - mean_absolute_error: 10.9056 - val_loss: 9.6626 - val_mean_absolute_error: 9.6626
# Epoch 59/100
# 1/1 [==============================] - 0s 27ms/step - loss: 11.0596 - mean_absolute_error: 11.0596 - val_loss: 9.7498 - val_mean_absolute_error: 9.7498
# Epoch 60/100
# 1/1 [==============================] - 0s 27ms/step - loss: 11.0854 - mean_absolute_error: 11.0854 - val_loss: 9.5929 - val_mean_absolute_error: 9.5929
# Epoch 61/100
# 1/1 [==============================] - 0s 25ms/step - loss: 10.9671 - mean_absolute_error: 10.9671 - val_loss: 9.2091 - val_mean_absolute_error: 9.2091
# Epoch 62/100
# 1/1 [==============================] - 0s 26ms/step - loss: 10.7162 - mean_absolute_error: 10.7162 - val_loss: 8.7122 - val_mean_absolute_error: 8.7122
# Epoch 63/100
# 1/1 [==============================] - 0s 26ms/step - loss: 10.3873 - mean_absolute_error: 10.3873 - val_loss: 8.4450 - val_mean_absolute_error: 8.4450
# Epoch 64/100
# 1/1 [==============================] - 0s 27ms/step - loss: 10.1198 - mean_absolute_error: 10.1198 - val_loss: 8.4393 - val_mean_absolute_error: 8.4393
# Epoch 65/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.9232 - mean_absolute_error: 9.9232 - val_loss: 8.6293 - val_mean_absolute_error: 8.6293
# Epoch 66/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.8066 - mean_absolute_error: 9.8066 - val_loss: 9.0425 - val_mean_absolute_error: 9.0425
# Epoch 67/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.8190 - mean_absolute_error: 9.8190 - val_loss: 9.4468 - val_mean_absolute_error: 9.4468
# Epoch 68/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.8845 - mean_absolute_error: 9.8845 - val_loss: 9.6843 - val_mean_absolute_error: 9.6843
# Epoch 69/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.8989 - mean_absolute_error: 9.8989 - val_loss: 9.7369 - val_mean_absolute_error: 9.7369
# Epoch 70/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.8359 - mean_absolute_error: 9.8359 - val_loss: 9.6115 - val_mean_absolute_error: 9.6115
# Epoch 71/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.7029 - mean_absolute_error: 9.7029 - val_loss: 9.3535 - val_mean_absolute_error: 9.3535
# Epoch 72/100
# 1/1 [==============================] - 0s 28ms/step - loss: 9.5328 - mean_absolute_error: 9.5328 - val_loss: 9.1193 - val_mean_absolute_error: 9.1193
# Epoch 73/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.3980 - mean_absolute_error: 9.3980 - val_loss: 8.9585 - val_mean_absolute_error: 8.9585
# Epoch 74/100
# 1/1 [==============================] - 0s 25ms/step - loss: 9.3087 - mean_absolute_error: 9.3087 - val_loss: 8.8346 - val_mean_absolute_error: 8.8346
# Epoch 75/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.2523 - mean_absolute_error: 9.2523 - val_loss: 8.8487 - val_mean_absolute_error: 8.8487
# Epoch 76/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.2399 - mean_absolute_error: 9.2399 - val_loss: 8.9594 - val_mean_absolute_error: 8.9594
# Epoch 77/100
# 1/1 [==============================] - 0s 28ms/step - loss: 9.2376 - mean_absolute_error: 9.2376 - val_loss: 9.0072 - val_mean_absolute_error: 9.0072
# Epoch 78/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.2146 - mean_absolute_error: 9.2146 - val_loss: 8.9921 - val_mean_absolute_error: 8.9921
# Epoch 79/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.1678 - mean_absolute_error: 9.1678 - val_loss: 8.9268 - val_mean_absolute_error: 8.9268
# Epoch 80/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.0977 - mean_absolute_error: 9.0977 - val_loss: 8.8121 - val_mean_absolute_error: 8.8121
# Epoch 81/100
# 1/1 [==============================] - 0s 27ms/step - loss: 9.0137 - mean_absolute_error: 9.0137 - val_loss: 8.6769 - val_mean_absolute_error: 8.6769
# Epoch 82/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.9248 - mean_absolute_error: 8.9248 - val_loss: 8.6626 - val_mean_absolute_error: 8.6626
# Epoch 83/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.8779 - mean_absolute_error: 8.8779 - val_loss: 8.6836 - val_mean_absolute_error: 8.6836
# Epoch 84/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.8555 - mean_absolute_error: 8.8555 - val_loss: 8.6901 - val_mean_absolute_error: 8.6901
# Epoch 85/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.8535 - mean_absolute_error: 8.8535 - val_loss: 8.6863 - val_mean_absolute_error: 8.6863
# Epoch 86/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.8464 - mean_absolute_error: 8.8464 - val_loss: 8.6649 - val_mean_absolute_error: 8.6649
# Epoch 87/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.8301 - mean_absolute_error: 8.8301 - val_loss: 8.5963 - val_mean_absolute_error: 8.5963
# Epoch 88/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.7994 - mean_absolute_error: 8.7994 - val_loss: 8.4862 - val_mean_absolute_error: 8.4862
# Epoch 89/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.7587 - mean_absolute_error: 8.7587 - val_loss: 8.3873 - val_mean_absolute_error: 8.3873
# Epoch 90/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.7244 - mean_absolute_error: 8.7244 - val_loss: 8.3012 - val_mean_absolute_error: 8.3012
# Epoch 91/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.6919 - mean_absolute_error: 8.6919 - val_loss: 8.2199 - val_mean_absolute_error: 8.2199
# Epoch 92/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.6634 - mean_absolute_error: 8.6634 - val_loss: 8.1529 - val_mean_absolute_error: 8.1529
# Epoch 93/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.6415 - mean_absolute_error: 8.6415 - val_loss: 8.1527 - val_mean_absolute_error: 8.1527
# Epoch 94/100
# 1/1 [==============================] - 0s 28ms/step - loss: 8.6307 - mean_absolute_error: 8.6307 - val_loss: 8.1690 - val_mean_absolute_error: 8.1690
# Epoch 95/100
# 1/1 [==============================] - 0s 28ms/step - loss: 8.6194 - mean_absolute_error: 8.6194 - val_loss: 8.1658 - val_mean_absolute_error: 8.1658
# Epoch 96/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.5957 - mean_absolute_error: 8.5957 - val_loss: 8.1509 - val_mean_absolute_error: 8.1509
# Epoch 97/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.5651 - mean_absolute_error: 8.5651 - val_loss: 8.1285 - val_mean_absolute_error: 8.1285
# Epoch 98/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.5292 - mean_absolute_error: 8.5292 - val_loss: 8.1423 - val_mean_absolute_error: 8.1423
# Epoch 99/100
# 1/1 [==============================] - 0s 40ms/step - loss: 8.4992 - mean_absolute_error: 8.4992 - val_loss: 8.1958 - val_mean_absolute_error: 8.1958
# Epoch 100/100
# 1/1 [==============================] - 0s 30ms/step - loss: 8.4755 - mean_absolute_error: 8.4755 - val_loss: 8.2488 - val_mean_absolute_error: 8.2488
# 1/1 [==============================] - 0s 62ms/step
# Model predicted negative numbers. Retraining...
# Epoch 1/100
# 1/1 [==============================] - 1s 974ms/step - loss: 8.4560 - mean_absolute_error: 8.4560 - val_loss: 8.2828 - val_mean_absolute_error: 8.2828
# Epoch 2/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.4395 - mean_absolute_error: 8.4395 - val_loss: 8.2978 - val_mean_absolute_error: 8.2978
# Epoch 3/100
# 1/1 [==============================] - 0s 33ms/step - loss: 8.4158 - mean_absolute_error: 8.4158 - val_loss: 8.2935 - val_mean_absolute_error: 8.2935
# Epoch 4/100
# 1/1 [==============================] - 0s 28ms/step - loss: 8.3863 - mean_absolute_error: 8.3863 - val_loss: 8.2787 - val_mean_absolute_error: 8.2787
# Epoch 5/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.3596 - mean_absolute_error: 8.3596 - val_loss: 8.3126 - val_mean_absolute_error: 8.3126
# Epoch 6/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.3424 - mean_absolute_error: 8.3424 - val_loss: 8.3478 - val_mean_absolute_error: 8.3478
# Epoch 7/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.3275 - mean_absolute_error: 8.3275 - val_loss: 8.3556 - val_mean_absolute_error: 8.3556
# Epoch 8/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.3120 - mean_absolute_error: 8.3120 - val_loss: 8.3356 - val_mean_absolute_error: 8.3356
# Epoch 9/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.2880 - mean_absolute_error: 8.2880 - val_loss: 8.2955 - val_mean_absolute_error: 8.2955
# Epoch 10/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.2595 - mean_absolute_error: 8.2595 - val_loss: 8.2386 - val_mean_absolute_error: 8.2386
# Epoch 11/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.2334 - mean_absolute_error: 8.2334 - val_loss: 8.2109 - val_mean_absolute_error: 8.2109
# Epoch 12/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.2184 - mean_absolute_error: 8.2184 - val_loss: 8.1898 - val_mean_absolute_error: 8.1898
# Epoch 13/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.2039 - mean_absolute_error: 8.2039 - val_loss: 8.1462 - val_mean_absolute_error: 8.1462
# Epoch 14/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.1793 - mean_absolute_error: 8.1793 - val_loss: 8.0937 - val_mean_absolute_error: 8.0937
# Epoch 15/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.1518 - mean_absolute_error: 8.1518 - val_loss: 8.0858 - val_mean_absolute_error: 8.0858
# Epoch 16/100
# 1/1 [==============================] - 0s 25ms/step - loss: 8.1315 - mean_absolute_error: 8.1315 - val_loss: 8.0935 - val_mean_absolute_error: 8.0935
# Epoch 17/100
# 1/1 [==============================] - 0s 24ms/step - loss: 8.1190 - mean_absolute_error: 8.1190 - val_loss: 8.0784 - val_mean_absolute_error: 8.0784
# Epoch 18/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.1012 - mean_absolute_error: 8.1012 - val_loss: 8.0403 - val_mean_absolute_error: 8.0403
# Epoch 19/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.0747 - mean_absolute_error: 8.0747 - val_loss: 7.9929 - val_mean_absolute_error: 7.9929
# Epoch 20/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.0479 - mean_absolute_error: 8.0479 - val_loss: 7.9829 - val_mean_absolute_error: 7.9829
# Epoch 21/100
# 1/1 [==============================] - 0s 26ms/step - loss: 8.0339 - mean_absolute_error: 8.0339 - val_loss: 7.9848 - val_mean_absolute_error: 7.9848
# Epoch 22/100
# 1/1 [==============================] - 0s 24ms/step - loss: 8.0160 - mean_absolute_error: 8.0160 - val_loss: 7.9434 - val_mean_absolute_error: 7.9434
# Epoch 23/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.9842 - mean_absolute_error: 7.9842 - val_loss: 7.9471 - val_mean_absolute_error: 7.9471
# Epoch 24/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.9676 - mean_absolute_error: 7.9676 - val_loss: 7.9575 - val_mean_absolute_error: 7.9575
# Epoch 25/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.9578 - mean_absolute_error: 7.9578 - val_loss: 7.9452 - val_mean_absolute_error: 7.9452
# Epoch 26/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.9438 - mean_absolute_error: 7.9438 - val_loss: 7.9256 - val_mean_absolute_error: 7.9256
# Epoch 27/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.9266 - mean_absolute_error: 7.9266 - val_loss: 7.9141 - val_mean_absolute_error: 7.9141
# Epoch 28/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.9119 - mean_absolute_error: 7.9119 - val_loss: 7.8881 - val_mean_absolute_error: 7.8881
# Epoch 29/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.8963 - mean_absolute_error: 7.8963 - val_loss: 7.8537 - val_mean_absolute_error: 7.8537
# Epoch 30/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.8791 - mean_absolute_error: 7.8791 - val_loss: 7.8110 - val_mean_absolute_error: 7.8110
# Epoch 31/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.8622 - mean_absolute_error: 7.8622 - val_loss: 7.7621 - val_mean_absolute_error: 7.7621
# Epoch 32/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.8460 - mean_absolute_error: 7.8460 - val_loss: 7.7183 - val_mean_absolute_error: 7.7183
# Epoch 33/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.8302 - mean_absolute_error: 7.8302 - val_loss: 7.6893 - val_mean_absolute_error: 7.6893
# Epoch 34/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.8145 - mean_absolute_error: 7.8145 - val_loss: 7.6641 - val_mean_absolute_error: 7.6641
# Epoch 35/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.8003 - mean_absolute_error: 7.8003 - val_loss: 7.6415 - val_mean_absolute_error: 7.6415
# Epoch 36/100
# 1/1 [==============================] - 0s 28ms/step - loss: 7.7886 - mean_absolute_error: 7.7886 - val_loss: 7.6328 - val_mean_absolute_error: 7.6328
# Epoch 37/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.7741 - mean_absolute_error: 7.7741 - val_loss: 7.6594 - val_mean_absolute_error: 7.6594
# Epoch 38/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.7628 - mean_absolute_error: 7.7628 - val_loss: 7.6613 - val_mean_absolute_error: 7.6613
# Epoch 39/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.7501 - mean_absolute_error: 7.7501 - val_loss: 7.6414 - val_mean_absolute_error: 7.6414
# Epoch 40/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.7347 - mean_absolute_error: 7.7347 - val_loss: 7.6336 - val_mean_absolute_error: 7.6336
# Epoch 41/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.7228 - mean_absolute_error: 7.7228 - val_loss: 7.6361 - val_mean_absolute_error: 7.6361
# Epoch 42/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.7099 - mean_absolute_error: 7.7099 - val_loss: 7.6430 - val_mean_absolute_error: 7.6430
# Epoch 43/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.6929 - mean_absolute_error: 7.6929 - val_loss: 7.6824 - val_mean_absolute_error: 7.6824
# Epoch 44/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.6813 - mean_absolute_error: 7.6813 - val_loss: 7.7005 - val_mean_absolute_error: 7.7005
# Epoch 45/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.6690 - mean_absolute_error: 7.6690 - val_loss: 7.6939 - val_mean_absolute_error: 7.6939
# Epoch 46/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.6541 - mean_absolute_error: 7.6541 - val_loss: 7.6684 - val_mean_absolute_error: 7.6684
# Epoch 47/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.6362 - mean_absolute_error: 7.6362 - val_loss: 7.6758 - val_mean_absolute_error: 7.6758
# Epoch 48/100
# 1/1 [==============================] - 0s 32ms/step - loss: 7.6278 - mean_absolute_error: 7.6278 - val_loss: 7.6971 - val_mean_absolute_error: 7.6971
# Epoch 49/100
# 1/1 [==============================] - 0s 36ms/step - loss: 7.6098 - mean_absolute_error: 7.6098 - val_loss: 7.7483 - val_mean_absolute_error: 7.7483
# Epoch 50/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.5937 - mean_absolute_error: 7.5937 - val_loss: 7.7887 - val_mean_absolute_error: 7.7887
# Epoch 51/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.5821 - mean_absolute_error: 7.5821 - val_loss: 7.7938 - val_mean_absolute_error: 7.7938
# Epoch 52/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.5650 - mean_absolute_error: 7.5650 - val_loss: 7.7676 - val_mean_absolute_error: 7.7676
# Epoch 53/100
# 1/1 [==============================] - 0s 28ms/step - loss: 7.5435 - mean_absolute_error: 7.5435 - val_loss: 7.7370 - val_mean_absolute_error: 7.7370
# Epoch 54/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.5352 - mean_absolute_error: 7.5352 - val_loss: 7.7329 - val_mean_absolute_error: 7.7329
# Epoch 55/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.5207 - mean_absolute_error: 7.5207 - val_loss: 7.7583 - val_mean_absolute_error: 7.7583
# Epoch 56/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.4991 - mean_absolute_error: 7.4991 - val_loss: 7.8064 - val_mean_absolute_error: 7.8064
# Epoch 57/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.4917 - mean_absolute_error: 7.4917 - val_loss: 7.8334 - val_mean_absolute_error: 7.8334
# Epoch 58/100
# 1/1 [==============================] - 0s 32ms/step - loss: 7.4811 - mean_absolute_error: 7.4811 - val_loss: 7.8363 - val_mean_absolute_error: 7.8363
# Epoch 59/100
# 1/1 [==============================] - 0s 32ms/step - loss: 7.4641 - mean_absolute_error: 7.4641 - val_loss: 7.8131 - val_mean_absolute_error: 7.8131
# Epoch 60/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.4409 - mean_absolute_error: 7.4409 - val_loss: 7.8001 - val_mean_absolute_error: 7.8001
# Epoch 61/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.4207 - mean_absolute_error: 7.4207 - val_loss: 7.8278 - val_mean_absolute_error: 7.8278
# Epoch 62/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.4099 - mean_absolute_error: 7.4099 - val_loss: 7.8593 - val_mean_absolute_error: 7.8593
# Epoch 63/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.3846 - mean_absolute_error: 7.3846 - val_loss: 7.8889 - val_mean_absolute_error: 7.8889
# Epoch 64/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.3596 - mean_absolute_error: 7.3596 - val_loss: 7.9457 - val_mean_absolute_error: 7.9457
# Epoch 65/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.3385 - mean_absolute_error: 7.3385 - val_loss: 7.9930 - val_mean_absolute_error: 7.9930
# Epoch 66/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.3164 - mean_absolute_error: 7.3164 - val_loss: 8.0011 - val_mean_absolute_error: 8.0011
# Epoch 67/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.2895 - mean_absolute_error: 7.2895 - val_loss: 7.9814 - val_mean_absolute_error: 7.9814
# Epoch 68/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.2649 - mean_absolute_error: 7.2649 - val_loss: 7.9735 - val_mean_absolute_error: 7.9735
# Epoch 69/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.2481 - mean_absolute_error: 7.2481 - val_loss: 7.9559 - val_mean_absolute_error: 7.9559
# Epoch 70/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.2289 - mean_absolute_error: 7.2289 - val_loss: 7.9250 - val_mean_absolute_error: 7.9250
# Epoch 71/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.2024 - mean_absolute_error: 7.2024 - val_loss: 7.8942 - val_mean_absolute_error: 7.8942
# Epoch 72/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.1714 - mean_absolute_error: 7.1714 - val_loss: 7.8631 - val_mean_absolute_error: 7.8631
# Epoch 73/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.1439 - mean_absolute_error: 7.1439 - val_loss: 7.8512 - val_mean_absolute_error: 7.8512
# Epoch 74/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.1196 - mean_absolute_error: 7.1196 - val_loss: 7.8255 - val_mean_absolute_error: 7.8255
# Epoch 75/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.0936 - mean_absolute_error: 7.0936 - val_loss: 7.7760 - val_mean_absolute_error: 7.7760
# Epoch 76/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.0616 - mean_absolute_error: 7.0616 - val_loss: 7.7516 - val_mean_absolute_error: 7.7516
# Epoch 77/100
# 1/1 [==============================] - 0s 27ms/step - loss: 7.0421 - mean_absolute_error: 7.0421 - val_loss: 7.7321 - val_mean_absolute_error: 7.7321
# Epoch 78/100
# 1/1 [==============================] - 0s 26ms/step - loss: 7.0245 - mean_absolute_error: 7.0245 - val_loss: 7.7163 - val_mean_absolute_error: 7.7163
# Epoch 79/100
# 1/1 [==============================] - 0s 25ms/step - loss: 7.0028 - mean_absolute_error: 7.0028 - val_loss: 7.6921 - val_mean_absolute_error: 7.6921
# Epoch 80/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.9747 - mean_absolute_error: 6.9747 - val_loss: 7.7032 - val_mean_absolute_error: 7.7032
# Epoch 81/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.9559 - mean_absolute_error: 6.9559 - val_loss: 7.6984 - val_mean_absolute_error: 7.6984
# Epoch 82/100
# 1/1 [==============================] - 0s 28ms/step - loss: 6.9324 - mean_absolute_error: 6.9324 - val_loss: 7.6608 - val_mean_absolute_error: 7.6608
# Epoch 83/100
# 1/1 [==============================] - 0s 28ms/step - loss: 6.9049 - mean_absolute_error: 6.9049 - val_loss: 7.6311 - val_mean_absolute_error: 7.6311
# Epoch 84/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.8884 - mean_absolute_error: 6.8884 - val_loss: 7.5889 - val_mean_absolute_error: 7.5889
# Epoch 85/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.8632 - mean_absolute_error: 6.8632 - val_loss: 7.5680 - val_mean_absolute_error: 7.5680
# Epoch 86/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.8500 - mean_absolute_error: 6.8500 - val_loss: 7.4863 - val_mean_absolute_error: 7.4863
# Epoch 87/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.8282 - mean_absolute_error: 6.8282 - val_loss: 7.3677 - val_mean_absolute_error: 7.3677
# Epoch 88/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.8093 - mean_absolute_error: 6.8093 - val_loss: 7.2661 - val_mean_absolute_error: 7.2661
# Epoch 89/100
# 1/1 [==============================] - 0s 37ms/step - loss: 6.8022 - mean_absolute_error: 6.8022 - val_loss: 7.2281 - val_mean_absolute_error: 7.2281
# Epoch 90/100
# 1/1 [==============================] - 0s 35ms/step - loss: 6.7854 - mean_absolute_error: 6.7854 - val_loss: 7.2398 - val_mean_absolute_error: 7.2398
# Epoch 91/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.7677 - mean_absolute_error: 6.7677 - val_loss: 7.2662 - val_mean_absolute_error: 7.2662
# Epoch 92/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.7637 - mean_absolute_error: 6.7637 - val_loss: 7.2368 - val_mean_absolute_error: 7.2368
# Epoch 93/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.7542 - mean_absolute_error: 6.7542 - val_loss: 7.2317 - val_mean_absolute_error: 7.2317
# Epoch 94/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.7566 - mean_absolute_error: 6.7566 - val_loss: 7.2209 - val_mean_absolute_error: 7.2209
# Epoch 95/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.7460 - mean_absolute_error: 6.7460 - val_loss: 7.2107 - val_mean_absolute_error: 7.2107
# Epoch 96/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.7384 - mean_absolute_error: 6.7384 - val_loss: 7.1851 - val_mean_absolute_error: 7.1851
# Epoch 97/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.7318 - mean_absolute_error: 6.7318 - val_loss: 7.1083 - val_mean_absolute_error: 7.1083
# Epoch 98/100
# 1/1 [==============================] - 0s 26ms/step - loss: 6.7184 - mean_absolute_error: 6.7184 - val_loss: 7.0691 - val_mean_absolute_error: 7.0691
# Epoch 99/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.7295 - mean_absolute_error: 6.7295 - val_loss: 7.0718 - val_mean_absolute_error: 7.0718
# Epoch 100/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.7036 - mean_absolute_error: 6.7036 - val_loss: 7.1327 - val_mean_absolute_error: 7.1327
# 1/1 [==============================] - 0s 64ms/step
# Model did not predict negative numbers. Stopping training.
# 1/1 [==============================] - 0s 20ms/step - loss: 7.3477 - mean_absolute_error: 7.3477
# Test loss: [7.347714424133301, 7.347714424133301]
# 9/9 [==============================] - 0s 1ms/step
#         POA_CODE21   SA1_CODE21  TOTAL1       pred
# 0             3331  20301103507    11.0   1.295710
# 99            3217  20301103607    13.0  23.449446
# 6922          3240  20301103608     8.0   1.200609
# 7110          3216  20302103701    41.0  68.740494
# 29395         3220  20302103904    46.0  23.082899
# ...            ...          ...     ...        ...
# 1885970       3943  21402138327    19.0   4.548957
# 1886808       3940  21402138402     6.0   7.743480
# 1888933       3938  21402138409    17.0  14.261397
# 1890202       3913  21402138506     7.0   8.704976
# 1891491       3931  21402159101    26.0  40.613705
#
# [281 rows x 4 columns]
# 6215.0 5680.658
# 0.0 0.0

# %%
mlp_model.save("Data\my_model7.h5")
plt.savefig('Plots\learn_plot_my_model7.png')
# Out:
# c:\Users\danla\anaconda3\envs\fYP\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# # X_train, X_test, y_train, y_test = train_test_split(extended_data, extended_labels, test_size=0.2, random_state=42)
# X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# # Create a CNN model
# # mlp_model = Sequential([
# #     Dense(128, activation='relu', input_shape=(data.shape[1],)),
# #     # Dropout(0.1),  # Add dropout layer with dropout rate of 0.3
# #     Dense(64, activation='relu'),
# #     # Dropout(0.1),
# #     Dense(32, activation='relu'),
# #     # Dropout(0.1),
# #     Dense(1)
# # ])

# mlp_model = Sequential([
#     Dense(128, activation='relu', input_shape=(data.shape[1],)),
#     # Dropout(0.01),  # Add dropout layer with dropout rate of 0.3
#     Dense(256, activation='relu'),
#     # Dropout(0.01),  # Add dropout layer with dropout rate of 0.3
#     Dense(512, activation='relu'),
#     # Dropout(0.01),  # Add dropout layer with dropout rate of 0.3
#     Dense(128, activation='relu'),
#     #Dropout(0.1),  # Add dropout layer with dropout rate of 0.3
#     Dense(64, activation='relu'),
#     # Dropout(0.1),
#     Dense(32, activation='relu'),
#     # Dropout(0.1),
#     Dense(1)
# ])

# def custom_loss(y_true, y_pred):
#     # Compute the mean squared error
#     mse = tf.reduce_mean(tf.square(y_true - y_pred))
    
#     # Penalize negative predictions (adjust the penalty weight as needed)
#     penalty = tf.reduce_mean(tf.square(tf.maximum(0.0, -y_pred)))
    
#     # Combine the MSE and penalty terms (adjust the weighting as needed)
#     total_loss = mse + penalty    
#     return total_loss

# # Compile the model with the specified optimizer and loss function
# optimizer = Adam(learning_rate=5e-6)
# mlp_model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mean_absolute_error'])

# # Reshape your data to add a channel dimension
# X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
# X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# # Train the model
# # while True:
# history = mlp_model.fit(X_train_cnn, y_train, epochs=300, batch_size=X_train.shape[0], validation_split=0.2)
#     # if mlp_model.predict(data).min() > -1 and mlp_model.predict(data).max() < 100:
#     #     break

# # Save the trained model
# mlp_model.save("Data\my_model1.3.h5")

# # Visualize the loss history


# predicted = mlp_model.predict(data)
# print(predicted.min() >= 0)
# # predicted[predicted < 0] = 0
# # rounded_predicted = np.round(predicted).astype(int)
# total_evs["pred"] = predicted
# pred_poa = poa.merge(total_evs, left_on="POA_CODE21", right_on="POA_CODE21", how="outer")
# pred_poa.loc[pd.isna(pred_poa["TOTAL1"]), "TOTAL1"] = 0
# pred_poa.loc[pd.isna(pred_poa["pred"]), "pred"] = 0


# # Plotting
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Loss Over Epochs')
# plt.legend()
# plt.show()

# # Evaluate the model on the test set
# loss = mlp_model.evaluate(X_test_cnn, y_test)
# print("Test loss:", loss)_poa["pred"].max(), pred_poa["TOTAL1"].max())

# fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# pred_poa.plot(column="pred", ax=axes[0], legend=True, cmap='viridis', vmax=max_value)
# axes[0].set_xticks([])
# axes[0].set_yticks([])
# axes[0].set_title("Predicted Data")

# pred_poa.plot(column="TOTAL1", ax=axes[1], legend=True, cmap='viridis', vmax=max_value)
# axes[1].set_xticks([])
# axes[1].set_yticks([])
# axes[1].set_title("Actual Data")

# plt.show()
# print(pred_poa["TOTAL1"].sum(), pred_poa["pred"].sum())
# pred_poa

# %%
pred_poa.mean()
# Out:
# C:\Users\danla\AppData\Local\Temp\ipykernel_12572\3876666263.py:1: FutureWarning: The default value of numeric_only in GeoDataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pred_poa.mean()
# POA_CODE21          inf
# TOTAL1        20.310458
# pred          19.722222
# dtype: float64

# %%
categorical_columns = ["dwelltype_Flat or Apartment", "dwelltype_Separate House", "dwelltype_Terrace/Townhouse",
                       "owndwell_Being Purchased", "owndwell_Being Rented", "owndwell_Fully Owned", "owndwell_Occupied Rent-Free"]

hist_values = []
num_bins = 10 

sa1_list = synthetic_merged["SA1"].unique()#[:4000]
i = 0

for sa1_selected in sa1_list:
    hist_values_sa1 = []
    selected = synthetic_merged[synthetic_merged["SA1"] == sa1_selected]

    i = i + 1
    if i % 100 == 0:  
        print(i)

    for attribute in ["INC", "TOTALVEHS", "HHSIZE"]:
        hist, _ = np.histogram(selected[attribute], bins=num_bins)
        hist_values_sa1.extend(hist)
    
    categorical_sums = selected[categorical_columns].sum().values
    hist_values_sa1.extend(categorical_sums)

    hist_values.append(hist_values_sa1)

data = np.array(hist_values)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900

# %%
sa1_pred = mlp_model.predict(data).flatten()
data = {'SA1': sa1_list, 'sa1_pred': sa1_pred}
df = pd.DataFrame(data)
df
# Out:
# 374/374 [==============================] - 0s 669us/step

# %%
unique_sa1_values  = synthetic_merged[["SA1", "geometry"]].drop_duplicates(subset="SA1")
mysa1_merge = unique_sa1_values.merge(df, on="SA1", how="left")
mysa1_merge.loc[pd.isna(mysa1_merge["sa1_pred"]), "sa1_pred"] = 0
mysa1_merge

# %%
pred_sa1_plot = sa1.merge(mysa1_merge[["SA1", "sa1_pred"]], left_on="SA1_CODE21", right_on="SA1", how='left')
pred_sa1_plot.loc[pd.isna(pred_sa1_plot["sa1_pred"]), "sa1_pred"] = 0
pred_sa1_plot
# Out:
#         SA1_CODE21 POA_CODE21  \
# 0      20102100908       3340
# 1      20102100910       3340
# 2      20301103507       3331
# 3      20301103607       3217
# 4      20301103608       3240
# ...            ...        ...
# 11946  21402159219       3931
# 11947  21402159220       3931
# 11948  21402159221       3931
# 11949  21402159222       3931
# 11950  21402159223       3931
#
#                                                 geometry          SA1  \
# 0      MULTIPOLYGON (((144.44381 -37.86401, 144.44362...          NaN
# 1      MULTIPOLYGON (((144.32480 -37.84446, 144.32497...          NaN
# 2      MULTIPOLYGON (((144.24563 -38.01367, 144.24580...  20301103507
# 3      MULTIPOLYGON (((144.29277 -38.26928, 144.29279...  20301103607
# 4      POLYGON ((144.24608 -38.21148, 144.24617 -38.2...  20301103608
# ...                                                  ...          ...
# 11946  POLYGON ((145.02982 -38.22619, 145.02947 -38.2...  21402159219
# 11947  POLYGON ((145.03348 -38.23112, 145.03351 -38.2...  21402159220
# 11948  POLYGON ((145.04023 -38.22754, 145.03973 -38.2...  21402159221
# 11949  POLYGON ((145.02819 -38.23559, 145.02932 -38.2...  21402159222
# 11950  POLYGON ((145.03212 -38.24210, 145.03205 -38.2...  21402159223
#
#        sa1_pred
# 0      0.000000
# 1      0.000000
# 2      0.367945
# 3      0.487588
# 4      0.292830
# ...         ...
# 11946  0.175484
# 11947  0.773148
# 11948  0.276295
# 11949  0.308920
# 11950  0.752853
#
# [11951 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the GeoDataFrame with the adjusted figure size
pred_sa1_plot.plot(column="sa1_pred", ax=ax)
# Out:
# <Axes: >
