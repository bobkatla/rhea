# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout

from feature_importance import process_from_census_data

# %%
sa1_data, sa1_tot = process_from_census_data(geo_lev="SA1", normalise=True, boxcox=False, keep_same=True, return_tot=True)
poa_data, poa_tot = process_from_census_data(geo_lev="POA", normalise=True, boxcox=False, keep_same=True, return_tot=True)

# %%
poa_data
# Out:
#       Fuel type__Not Applicable  Fuel type__Diesel  Fuel type__Electric  \
# 3000                   0.026178           0.430491             0.004934
# 3002                   0.021858           0.465919             0.009203
# 3003                   0.038632           0.199692             0.003652
# 3004                   0.021050           0.397259             0.010035
# 3006                   0.010449           0.308610             0.003197
# ...                         ...                ...                  ...
# 3990                   1.053571           1.750000             0.000000
# 3991                   0.421801           0.971564             0.000000
# 3992                   0.212171           0.598684             0.000000
# 3995                   0.180996           0.436782             0.002146
# 3996                   0.169331           0.403450             0.002103
#
#       Fuel type__Petrol  Fuel type__LPG/Dual fuel  \
# 3000           0.534101                  0.008388
# 3002           1.161346                  0.035088
# 3003           0.564482                  0.011724
# 3004           1.159711                  0.014564
# 3006           0.633151                  0.006852
# ...                 ...                       ...
# 3990           1.928571                  0.160714
# 3991           1.312796                  0.156398
# 3992           1.152961                  0.054276
# 3995           1.121992                  0.059617
# 3996           0.858645                  0.034287
#
#       Fuel type__Other and unknown  \
# 3000                      0.057726
# 3002                      0.041415
# 3003                      0.089564
# 3004                      0.049566
# 3006                      0.027978
# ...                            ...
# 3990                      0.982143
# 3991                      0.753555
# 3992                      0.376645
# 3995                      0.236628
# 3996                      0.270509
#
#       NPRD Number of Persons Usually Resident in Dwelling__One person  \
# 3000                                           0.301631
# 3002                                           0.297670
# 3003                                           0.289064
# 3004                                           0.314037
# 3006                                           0.291938
# ...                                                 ...
# 3990                                           0.107143
# 3991                                           0.175355
# 3992                                           0.220395
# 3995                                           0.254866
# 3996                                           0.169541
#
#       NPRD Number of Persons Usually Resident in Dwelling__Two persons  \
# 3000                                           0.247388
# 3002                                           0.293069
# 3003                                           0.305785
# 3004                                           0.291519
# 3006                                           0.287370
# ...                                                 ...
# 3990                                           0.357143
# 3991                                           0.308057
# 3992                                           0.330592
# 3995                                           0.281073
# 3996                                           0.247371
#
#       NPRD Number of Persons Usually Resident in Dwelling__Three persons  \
# 3000                                           0.058800
# 3002                                           0.054645
# 3003                                           0.091486
# 3004                                           0.062538
# 3006                                           0.073084
# ...                                                 ...
# 3990                                           0.142857
# 3991                                           0.075829
# 3992                                           0.118421
# 3995                                           0.096398
# 3996                                           0.052798
#
#       NPRD Number of Persons Usually Resident in Dwelling__Four persons  ...  \
# 3000                                           0.019039                  ...
# 3002                                           0.029048                  ...
# 3003                                           0.042860                  ...
# 3004                                           0.027781                  ...
# 3006                                           0.023638                  ...
# ...                                                 ...                  ...
# 3990                                           0.071429                  ...
# 3991                                           0.090047                  ...
# 3992                                           0.098684                  ...
# 3995                                           0.069119                  ...
# 3996                                           0.062894                  ...
#
#       TENLLD Tenure and Landlord Type__Owned with a mortgage  \
# 3000                                           0.071599
# 3002                                           0.125683
# 3003                                           0.153181
# 3004                                           0.148085
# 3006                                           0.122416
# ...                                                 ...
# 3990                                           0.285714
# 3991                                           0.241706
# 3992                                           0.376645
# 3995                                           0.203218
# 3996                                           0.145772
#
#       TENLLD Tenure and Landlord Type__Rented: Real estate agent  \
# 3000                                           0.422365
# 3002                                           0.311763
# 3003                                           0.417836
# 3004                                           0.346469
# 3006                                           0.416353
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.014218
# 3992                                           0.042763
# 3995                                           0.099770
# 3996                                           0.065629
#
#       TENLLD Tenure and Landlord Type__Rented: State or territory housing authority  \
# 3000                                           0.000929
# 3002                                           0.001150
# 3003                                           0.008841
# 3004                                           0.001224
# 3006                                           0.000228
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.000000
# 3992                                           0.000000
# 3995                                           0.024981
# 3996                                           0.007783
#
#       TENLLD Tenure and Landlord Type__Rented: Community housing provider  \
# 3000                                           0.004034
# 3002                                           0.000000
# 3003                                           0.005189
# 3004                                           0.001101
# 3006                                           0.000571
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.000000
# 3992                                           0.000000
# 3995                                           0.007203
# 3996                                           0.003366
#
#       TENLLD Tenure and Landlord Type__Rented: Person not in same household  \
# 3000                                           0.047249
# 3002                                           0.057233
# 3003                                           0.051701
# 3004                                           0.039897
# 3006                                           0.042537
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.066351
# 3992                                           0.047697
# 3995                                           0.038621
# 3996                                           0.024821
#
#       TENLLD Tenure and Landlord Type__Rented: Other landlord type  \
# 3000                                           0.008329
# 3002                                           0.003739
# 3003                                           0.006150
# 3004                                           0.004039
# 3006                                           0.003597
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.000000
# 3992                                           0.000000
# 3995                                           0.004444
# 3996                                           0.002735
#
#       TENLLD Tenure and Landlord Type__Rented: Landlord type not stated  \
# 3000                                           0.001567
# 3002                                           0.000000
# 3003                                           0.000000
# 3004                                           0.001469
# 3006                                           0.001028
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.000000
# 3992                                           0.000000
# 3995                                           0.001226
# 3996                                           0.000000
#
#       TENLLD Tenure and Landlord Type__Other tenure type  \
# 3000                                           0.013699
# 3002                                           0.012079
# 3003                                           0.010955
# 3004                                           0.011994
# 3006                                           0.012162
# ...                                                 ...
# 3990                                           0.000000
# 3991                                           0.042654
# 3992                                           0.019737
# 3995                                           0.013793
# 3996                                           0.011990
#
#       TENLLD Tenure and Landlord Type__Tenure type not stated  \
# 3000                                           0.062369
# 3002                                           0.038251
# 3003                                           0.040938
# 3004                                           0.055195
# 3006                                           0.041395
# ...                                                 ...
# 3990                                           0.053571
# 3991                                           0.127962
# 3992                                           0.074013
# 3995                                           0.048582
# 3996                                           0.024611
#
#       TENLLD Tenure and Landlord Type__Tenure type not applicable
# 3000                                           0.301080
# 3002                                           0.253955
# 3003                                           0.215068
# 3004                                           0.235345
# 3006                                           0.272011
# ...                                                 ...
# 3990                                           0.232143
# 3991                                           0.208531
# 3992                                           0.118421
# 3995                                           0.203065
# 3996                                           0.388936
#
# [691 rows x 72 columns]

# %%
drop_col = [x for x in poa_data.columns if "Fuel type" in x]
electric_vals = poa_data["Fuel type__Electric"]
poa_data = poa_data.drop(columns=drop_col)

# %%
check = poa_tot * electric_vals
check.sum()
# Out:
# 7819.0

# %%
# Create a CNN model
cnn_model = Sequential([
    Dense(128, activation='relu', input_shape=(66,)),
    Dropout(0.3),  # Add dropout layer with dropout rate of 0.3
    Dense(132, activation='relu'),
    Dropout(0.3),  # Add dropout layer with dropout rate of 0.3
    Dense(1)
])

X_train = poa_data
y_train = electric_vals

# Compile the model with the specified optimizer and loss function
optimizer = Adam(learning_rate=0.01)
cnn_model.compile(optimizer=optimizer, loss='mean_absolute_error', metrics=['mean_absolute_error'])

# Reshape your data to add a channel dimension
X_train_cnn = X_train.values.reshape(X_train.shape[0], X_train.shape[1], 1)

# Train the model
history = cnn_model.fit(X_train_cnn, y_train, epochs=30, batch_size=X_train.shape[0], validation_split=0.4)

# Save the trained model
# cnn_model.save("my_model2.h5")

# Visualize the loss history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.show()
# Out:
# Epoch 1/30
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0774 - mean_absolute_error: 0.0774 - val_loss: 0.6869 - val_mean_absolute_error: 0.6869
# Epoch 2/30
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6586 - mean_absolute_error: 0.6586 - val_loss: 0.2683 - val_mean_absolute_error: 0.2683
# Epoch 3/30
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2711 - mean_absolute_error: 0.2711 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166
# Epoch 4/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0338 - mean_absolute_error: 0.0338 - val_loss: 0.1146 - val_mean_absolute_error: 0.1146
# Epoch 5/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1003 - mean_absolute_error: 0.1003 - val_loss: 0.0805 - val_mean_absolute_error: 0.0805
# Epoch 6/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0740 - mean_absolute_error: 0.0740 - val_loss: 0.0316 - val_mean_absolute_error: 0.0316
# Epoch 7/30
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086
# Epoch 8/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0140 - mean_absolute_error: 0.0140 - val_loss: 0.0192 - val_mean_absolute_error: 0.0192
# Epoch 9/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0221 - mean_absolute_error: 0.0221 - val_loss: 0.0176 - val_mean_absolute_error: 0.0176
# Epoch 10/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0184 - mean_absolute_error: 0.0184 - val_loss: 0.0086 - val_mean_absolute_error: 0.0086
# Epoch 11/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - val_loss: 0.0035 - val_mean_absolute_error: 0.0035
# Epoch 12/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0074 - mean_absolute_error: 0.0074 - val_loss: 0.0062 - val_mean_absolute_error: 0.0062
# Epoch 13/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - val_loss: 0.0051 - val_mean_absolute_error: 0.0051
# Epoch 14/30
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0075 - mean_absolute_error: 0.0075 - val_loss: 0.0034 - val_mean_absolute_error: 0.0034
# Epoch 15/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - val_loss: 0.0019 - val_mean_absolute_error: 0.0019
# Epoch 16/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0036 - mean_absolute_error: 0.0036 - val_loss: 0.0023 - val_mean_absolute_error: 0.0023
# Epoch 17/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - val_loss: 0.0028 - val_mean_absolute_error: 0.0028
# Epoch 18/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0048 - mean_absolute_error: 0.0048 - val_loss: 0.0018 - val_mean_absolute_error: 0.0018
# Epoch 19/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.0022 - val_mean_absolute_error: 0.0022
# Epoch 20/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0029 - mean_absolute_error: 0.0029 - val_loss: 0.0032 - val_mean_absolute_error: 0.0032
# Epoch 21/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0035 - mean_absolute_error: 0.0035 - val_loss: 0.0036 - val_mean_absolute_error: 0.0036
# Epoch 22/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0038 - mean_absolute_error: 0.0038 - val_loss: 0.0031 - val_mean_absolute_error: 0.0031
# Epoch 23/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0034 - mean_absolute_error: 0.0034 - val_loss: 0.0021 - val_mean_absolute_error: 0.0021
# Epoch 24/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0027 - mean_absolute_error: 0.0027 - val_loss: 0.0017 - val_mean_absolute_error: 0.0017
# Epoch 25/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0028 - mean_absolute_error: 0.0028 - val_loss: 0.0027 - val_mean_absolute_error: 0.0027
# Epoch 26/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0037 - mean_absolute_error: 0.0037 - val_loss: 0.0023 - val_mean_absolute_error: 0.0023
# Epoch 27/30
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0033 - mean_absolute_error: 0.0033 - val_loss: 0.0018 - val_mean_absolute_error: 0.0018
# Epoch 28/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0025 - mean_absolute_error: 0.0025 - val_loss: 0.0026 - val_mean_absolute_error: 0.0026
# Epoch 29/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0029 - mean_absolute_error: 0.0029 - val_loss: 0.0031 - val_mean_absolute_error: 0.0031
# Epoch 30/30
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0033 - mean_absolute_error: 0.0033 - val_loss: 0.0030 - val_mean_absolute_error: 0.0030

# %%
def TRS(initial_weights, know_tot=None):
    # Desired total constraint
    desired_total = know_tot if know_tot else sum(initial_weights)

    # Step 1: Truncate the weights to integers
    truncated_weights = np.floor(initial_weights).astype(int)

    # Step 2: Calculate the discrepancy
    total_truncated = np.sum(truncated_weights)
    discrepancy = desired_total - total_truncated

    # Step 3: Replicate individuals to match the constraint
    if discrepancy > 0:
        # Calculate fractional parts
        fractional_parts = initial_weights - truncated_weights
        
        # Replicate individuals in proportion to their fractional parts
        replication_probs = fractional_parts / np.sum(fractional_parts)
        num_replications = np.random.multinomial(int(discrepancy), replication_probs)
        truncated_weights += num_replications

    # Step 4: Sample individuals if there is an excess
    if discrepancy < 0:
        excess_indices = np.where(truncated_weights > 0)[0]
        excess_weights = truncated_weights[excess_indices]
        
        # Calculate sampling probabilities based on truncated weights
        sampling_probs = excess_weights / np.sum(excess_weights)
        
        # Randomly sample individuals to reduce excess
        num_samples = np.random.multinomial(abs(discrepancy), sampling_probs)
        truncated_weights[excess_indices] -= num_samples

    # Step 5: Your final truncated and rounded integer weights
    return truncated_weights

# %%
cnn_model

# %%
predicted = cnn_model.predict(sa1_data)
predicted = predicted.flatten()
sa1_data["pred_num_EV_percen"] = predicted
sa1_data["pred_num_EV_percen"]
# Out:
# 484/484 [==============================] - 1s 2ms/step
# 20101100101    0.003318
# 20101100102    0.003318
# 20101100105    0.003318
# 20101100106    0.003318
# 20101100107    0.003318
#                  ...
# 21704148034    0.003318
# 21704148035    0.003318
# 29797979991    0.003549
# 29797979992    0.003549
# 29797979993    0.003549
# Name: pred_num_EV_percen, Length: 15481, dtype: float32

# %%
predicted_num = sa1_data["pred_num_EV_percen"] * sa1_tot

predicted_num = predicted_num.fillna(0) #na value because that sa1 has no one
predicted_rounded = TRS(predicted_num, know_tot=check.sum())

print(predicted_num.sum(), predicted_rounded.sum(), check.sum())

sa1_data["pred_num_EV"] = predicted_rounded
sa1_data["pred_num_EV"]
# Out:
# 9382.061174754752 7819 7819.0
# 20101100101    1
# 20101100102    1
# 20101100105    1
# 20101100106    0
# 20101100107    2
#               ..
# 21704148034    0
# 21704148035    1
# 29797979991    0
# 29797979992    0
# 29797979993    0
# Name: pred_num_EV, Length: 15481, dtype: int32

# %%
ls_of_3000_sa1 = pd.read_csv("data/VIC3000_sa1.csv")
pred_ev_sa1 = pd.read_csv("output/EV_pred/results_EV_pred.csv")
ls_sa1 = ls_of_3000_sa1["SA1_CODE21"]
pred_ev_sa1 = pred_ev_sa1[pred_ev_sa1["SA1"].isin(ls_sa1)]
pred_ev_sa1
# Out:
#         hhsize          dwelltype   hhinc  totalvehs            owndwell  \
# 215697     4.0     Separate House  2700.0        3.0     Being Purchased
# 215698     4.0     Separate House  1974.0        2.0         Fully Owned
# 215699     4.0  Flat or Apartment  1400.0        1.0        Being Rented
# 215700     4.0     Separate House  1200.0        3.0         Fully Owned
# 215701     4.0     Separate House   900.0        4.0     Being Purchased
# ...        ...                ...     ...        ...                 ...
# 262812     1.0              Other  2500.0        0.0         Fully Owned
# 262813     1.0     Separate House  1375.0        1.0        Being Rented
# 262814     1.0  Terrace/Townhouse  2600.0        0.0  Occupied Rent-Free
# 262815     1.0  Flat or Apartment   350.0        1.0         Fully Owned
# 262816     1.0     Separate House  4875.0        1.0         Fully Owned
#
#           hhid   EV_pred          SA1
# 215697  215622 -0.001145  20604111738
# 215698  215623 -0.001275  20604111738
# 215699  215624  0.005310  20604111738
# 215700  215625  0.031688  20604111738
# 215701  215626 -0.018587  20604111738
# ...        ...       ...          ...
# 262812  262737  0.015806  20604150622
# 262813  262738 -0.010883  20604150622
# 262814  262739 -0.016413  20604150622
# 262815  262740 -0.003910  20604150622
# 262816  262741  0.038780  20604150622
#
# [21015 rows x 8 columns]

# %%
ls_EV = sa1_data[sa1_data.index.astype("str").isin(ls_sa1.astype("str"))]["pred_num_EV"]
ls_EV.sum()
# post code 3000 has 170 EV, very wrong
# Out:
# 117

# %%
final_vals_threshold = {
    "sa1": [],
    "thres": []
}
for sa1 in ls_sa1:
    check_df = pred_ev_sa1[pred_ev_sa1["SA1"]== sa1]
    if len(check_df) == 0:
        continue
    sa1_num_ev = ls_EV[ls_EV.index.astype("str") == str(sa1)].iloc[0]
    if sa1_num_ev == 0:
        continue
    else:
        sa1_num_ev -= 1
    check_df = check_df.sort_values("EV_pred", ascending=False)
    ls_EV_val_percen = check_df["EV_pred"]
    the_threshold = ls_EV_val_percen.iat[sa1_num_ev]
    final_vals_threshold["sa1"].append(sa1)
    final_vals_threshold["thres"].append(the_threshold)

# %%
thres_check_3000 =  pd.DataFrame(final_vals_threshold)
thres_check_3000
# Out:
#             sa1     thres
# 0   20604150529  0.058599
# 1   20604150527  0.054562
# 2   20604150524  0.076130
# 3   20604150522  0.058404
# 4   20604150521  0.059426
# ..          ...       ...
# 59  20604150307  0.058599
# 60  20604150306  0.053119
# 61  20604150305  0.081267
# 62  20604150301  0.058360
# 63  20604111746  0.097656
#
# [64 rows x 2 columns]

# %%
thres_check_3000["thres"].mean()
# Out:
# 0.07604650932730828

# %%
thres_check_3000["thres"].mode()
# Out:
# 0    0.058599
# Name: thres, dtype: float64

# %%
thres_check_3000["thres"].min()
# Out:
# 0.0442666468527368

# %%
thres_check_3000["thres"].max()
# Out:
# 0.2873587879936881
